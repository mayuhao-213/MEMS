# %% [markdown]
# # Piezoelectric Microcantilever Data Generator
#
# ## 1. 物理常数与参数设置
#
# ### 1.1 物理常数（固定不变）
#
# | 名称             | 变量名      | 数值            | 单位    | 含义         |
# |------------------|-------------|-----------------|---------|--------------|
# | 杨氏模量         | `E`         | 169e9           | Pa      | 弹性模量     |
# | 材料密度         | `rho`       | 2330            | kg/m³   | 硅密度       |
# | 梁厚度           | `t`         | 25e-6           | m       | 梁截面厚度   |
# | 真空介电常数     | `eps_0`     | 8.85e-12        | F/m     | 电场常数     |
# | 第一模态参数     | `beta`      | 4.73      | -       | 固定根值     |
#
# ### 1.2 结构/电气参数（可扩展为变量）
#
# | 名称               | 变量名            | 当前数值       | 单位   |采样点数| 说明              | 采样范围             |
# |--------------------|-------------------|---------------|--------|------|-------------------|-------------------------|
# | 梁宽               | `w_t`             | 10e-6         | m      | 16|梁的横向宽度      | [5e-6, 20e-6]           |
# | 梁长               | `l_t`             | 500e-6        | m      | 19|梁的长度          | [100e-6, 1000e-6]       |
# | 驱动电压           | `V`               | 5             | V      | 10|DC激励电压        | [1, 10]                 |
# | 电极间隙           | `d`               | 6e-6          | m      | 9|顶/底电极间距     | [2e-6, 10e-6]           |
# | 电极长度           | `electrode_length`| 700e-6        | m      | 81|电极长度          | [100e-6, 900e-6]        |
# | 电极宽度           | `electrode_width` | 20e-6         | m      | 26|电极宽度          | [5e-6, 30e-6]           |
# | 端部质量块宽度     | `w_c`             | 10e-6         | m      | 76|末端质量块宽度    | [5e-6, 20e-6]           |
# | 端部质量块长度     | `l_c`             | 20e-6         | m      | 26|末端质量块长度    | [5e-6, 30e-6]           |
# | 驱动Vac            | `Vac_ground`      | 5e-3          | V      | 1|小信号驱动电压    | 可微调                  |
# | 品质因子          | `Q`                 | 10000 | -    | 19|机械品质因子 |[5000, 47500]|
#
#
#
# ### 1.3 扫描参数
#
# | 名称 | 变量名   | 范围                 | 单位 | 采样点数 | 说明     |
# | -- | ----- | ------------------ | -- | ---- | ------ |
# | 梁宽 | `w_t` | \[5e-6, 20e-6]     | m  | 16   | 梁的横向宽度 |
# | 梁长 | `l_t` | \[100e-6, 1000e-6] | m  | 19   | 梁的长度   |

# %%
import numpy as np

# ==== 1.1 物理常数 ====
E = 169e9               # 杨氏模量 (Pa)
rho = 2330              # 密度 (kg/m^3)
t = 25e-6               # 梁厚度 (m)
eps_0 = 8.85e-12        # 真空介电常数 (F/m)
beta = 4.73         # 第一阶模态根

# ==== 1.2 结构/电气参数（可扩展为区间）====
V = 5                      # 驱动电压 (V)
d = 6e-6                   # 电极间隙 (m)
electrode_length = 700e-6  # 电极长度 (m)
electrode_width = 20e-6    # 电极宽度 (m)
w_c = 10e-6                # 端部质量块宽度 (m)
l_c = 20e-6                # 端部质量块长度 (m)
Vac_ground = 5e-3          # 驱动Vac (V)
Q = 10000
# ==== 1.3 Q扫描参数 ====
w_t_list = np.linspace(5e-6, 20e-6, 160)      # 梁宽
l_t_list = np.linspace(100e-6, 1000e-6, 190)  # 梁长

# ==== 1.4 模态系数 ====
def calc_alpha_n(beta):
    denominator = np.cosh(beta) - np.cos(beta)
    if np.abs(denominator) < 1e-10:
        raise ValueError("alpha_n denominator too small")
    return (np.sin(beta) - np.sinh(beta)) / denominator

alpha_n = calc_alpha_n(beta)

# ==== 1.5 参数集 ====
params = dict(
    E=E, rho=rho, t=t, eps_0=eps_0, beta=beta, alpha_n=alpha_n,
    V=V, d=d, electrode_length=electrode_length, electrode_width=electrode_width,
    w_c=w_c, l_c=l_c, Vac_ground=Vac_ground, Q=Q
)

print("常数与可调参数设置完成。")
# Out:
# 常数与可调参数设置完成。

# %% [markdown]
# ## 2. 数据预处理：模态函数与梁参数计算
#
# 本节将根据物理模型，对微梁的模态形状函数、归一化模态、质量系数、刚度系数等参数进行数值预处理。
# 所有步骤严格基于 Euler-Bernoulli 悬臂梁一阶模态理论，具体物理公式如下：
#
# ### 2.1 模态函数
#
# 模态函数的未归一化表达式为（见 PINNS_explonation.pdf）：
# $$
# \text{modeshape}_{\text{unnormalized}}(x) =
# - \left[
# -\sin\left(\frac{\beta x}{l_t}\right) +
# \sinh\left(\frac{\beta x}{l_t}\right) +
# \alpha_n\left(
# -\cos\left(\frac{\beta x}{l_t}\right) +
# \cosh\left(\frac{\beta x}{l_t}\right)
# \right)
# \right]
# $$
#
# 归一化模态函数为：
# $$
# \text{modeshape}_1(x) = \frac{\text{modeshape}_{\text{unnormalized}}(x)}{\max(\text{modeshape}_{\text{unnormalized}})}
# $$
#
# ### 2.2 梁参数的积分计算
#
# - 质量系数：
#   $$
#   m_{\text{coef}_b} = \int_0^{l_t} [\text{modeshape}_1(x)]^2 \frac{dx}{l_t}
#   $$
#
# - 刚度系数：
#   $$
#   k_{\text{coef}_b} = \int_0^{l_t} \left[\frac{d^2}{dx^2}\text{modeshape}_1(x)\right]^2 \frac{dx}{l_t}
#   $$
#   $$
#   k_{\text{coef}_b3} = \int_0^{l_t} \left[\frac{d}{dx}\text{modeshape}_1(x)\right]^2 \frac{dx}{l_t}
#   $$
#
# ### 2.3 梁刚度、三次刚度、质量、固有角频率
#
# - 梁的等效刚度：
#   $$
#   k_{tt} = \frac{k_{\text{coef}_b}}{12} E t \left(\frac{w_t}{l_t}\right)^3
#   $$
# - 三次刚度：
#   $$
#   k_{t3} = k_{\text{coef}_b3} E t \frac{w_t}{l_t^3}
#   $$
# - 质量：
#   $$
#   M = \rho\left( t w_t l_t m_{\text{coef}_b} + \text{electrode\_length} \times \text{electrode\_width} \times t + 2 w_c l_c t \right)
#   $$
# - 一阶固有角频率与频率：
#   $$
#   \omega_0 = \sqrt{\frac{k_t}{M}}
#   $$
#   $$
#   f_0 = \frac{\omega_0}{2\pi}
#   $$

# %%
import math
def simulate(w_t, l_t, params, numberofsmallelements=2000):
    # 1. 拿出必要参数
    E = params['E']
    rho = params['rho']
    t = params['t']
    beta = params['beta']
    alpha_n = params['alpha_n']
    electrode_length = params['electrode_length']
    electrode_width = params['electrode_width']
    w_c = params['w_c']
    l_c = params['l_c']
    
    # ---- 空间离散参数 ----
    length_x = np.linspace(0, l_t, numberofsmallelements, endpoint=False)
    
    # ---- 模态函数计算 ----
    modeshape_unnormalized = -(
        -np.sin(beta * length_x / l_t)
        + np.sinh(beta * length_x / l_t)
        + alpha_n * (-np.cos(beta * length_x / l_t) + np.cosh(beta * length_x / l_t))
    )
    max_mode = np.max(modeshape_unnormalized)
    if np.abs(max_mode) < 1e-12:
        raise ValueError("modeshape_unnormalized max too small!")
    modeshape1 = modeshape_unnormalized / max_mode
    
    # ---- 数值一二阶导数 ----
    second_derivative = (-1 / max_mode) * (beta ** 2) * (
        np.sin(beta * length_x / l_t)
        + np.sinh(beta * length_x / l_t)
        + alpha_n * (np.cos(beta * length_x / l_t) + np.cosh(beta * length_x / l_t))
    )
    first_derivative = (-1 / max_mode) * beta * (
        -np.cos(beta * length_x / l_t)
        + np.sinh(beta * length_x / l_t)
        + alpha_n * (np.sin(beta * length_x / l_t) + np.cosh(beta * length_x / l_t))
    )
    
    # ---- 积分求各系数 ----
    dx = length_x[1] - length_x[0]
    m_coef_b = np.sum(modeshape1 ** 2 * dx / l_t)
    k_coef_b = np.sum(second_derivative ** 2 * dx / l_t)
    k_coef_b3 = np.sum(first_derivative ** 2 * dx / l_t)
    
    # ---- 梁参数 ----
    k_tt = k_coef_b / 12 * E * t * ((w_t / l_t) ** 3)
    k_t3 = k_coef_b3 * E * t * w_t / (l_t ** 3)
    k_t = k_tt
    Mass = rho * (t * w_t * l_t * m_coef_b + electrode_length * electrode_width * t + w_c * l_c * t * 2)
    omega_0 = math.sqrt(k_t / Mass)
    freq_0 = omega_0 / (2 * math.pi)
    #print(f"预计算完成：m_coef_b={m_coef_b:.4e}, k_coef_b={k_coef_b:.4e}, k_coef_b3={k_coef_b3:.4e}")
    #print(f"k_tt={k_tt:.4e}, k_t3={k_t3:.4e}, Mass={Mass:.4e}, omega_0={omega_0:.4e}, freq_0={freq_0:.4e} Hz")
    # 结果字典，可扩展
    return {
        'w_t': w_t,
        'l_t': l_t,
        'm_coef_b': m_coef_b,
        'k_coef_b': k_coef_b,
        'k_coef_b3': k_coef_b3,
        'k_tt': k_tt,
        'k_t3': k_t3,
        'Mass': Mass,
        'omega_0': omega_0,
        'freq_0': freq_0
    }

# %% [markdown]
# ## 3. 小批次数据生成（W_t,L_t扫描）
#
# 本节我们以品质因子 $W_t , L_t $ 为变量，采样多个 $W_t , L_t$ 值，计算对应的微梁谐振频率响应（`freq`）和电流响应（`m_c`）。
# 每组$Q$下的响应对应161个激励相位点（$\phi$），形成一个完整的频谱曲线。
# 所有核心参数（如$E$、$\rho$、$t$、$Q$等）均在开头代码区集中定义。
# 数据最终以DataFrame结构保存，**主变量为W_t、L_t、freq、m_c**，其余所有常数参数合并进一个dict一同写入文件，便于后续Notebook调用。
#
# ### 3.1 主要计算公式说明
#
# - **阻尼系数 $c$**
#   $$
#   c = \frac{\sqrt{M k_t}}{Q}
#   $$
#
# - **谐振器动力学方程组（每个$\phi$点求解）：**
#   $$
#   \begin{cases}
#     -M\omega^2 y + (k_t - k_e)y + (k_{t3} - k_{e3})\frac{3}{4}y^3 - F_{ac}\cos(\phi) = 0 \\
#     c \omega y - F_{ac}\sin(\phi) = 0
#   \end{cases}
#   $$
#   - $F_{ac} = V_{ac} \cdot \mathrm{trans\_factor}$，为激励幅值
#
# - **筛选规则：**
#   仅保留 $0 < \omega_0/2 < \omega < 3\omega_0/2$ 的正实根作为物理有效解
#
# - **最终输出数据结构：**
#   - `w_t,l_t`（扫描变量）
#   - `freq`（长度161的频率响应数组）
#   - `m_c`（长度161的电流响应数组）
#   - 其余所有物理常数/参数打包进 `constants` dict，作为h5文件属性一起保存

# %%
import pandas as pd
import numpy as np
from sympy import symbols
from sympy.solvers.solveset import nonlinsolve

number_of_sim = 161
phi = np.linspace((10 / 180) * np.pi, (170 / 180) * np.pi, number_of_sim)


total = len(w_t_list) * len(l_t_list)
count = 0
results = []

for w_t in w_t_list:
    for l_t in l_t_list:
        # 1. 梁/模态参数计算
        res = simulate(w_t, l_t, params)
        k_t = res['k_tt']
        k_t3 = res['k_t3']
        Mass = res['Mass']
        freq_0 = res['freq_0']
        omega_0 = res['omega_0']
        m_coef_b = res['m_coef_b']
        k_coef_b = res['k_coef_b']
        k_coef_b3 = res['k_coef_b3']

        # 2. 电-机械耦合参数
        trans_factor = eps_0 * V * electrode_length * t / (d ** 2)
        k_e = 2 * trans_factor * V / d
        k_e3 = 4 * trans_factor * V / (d ** 3)
        c = np.sqrt(Mass * k_t) / Q

        # 3. 非线性谐振响应解
        freq = np.full(number_of_sim, np.nan)3
        m_c = np.full(number_of_sim, np.nan)
        for i in range(number_of_sim):
            vac = Vac_ground
            force_ac = vac * trans_factor
            x, y = symbols('x, y', reals=True)
            try:
                solutions = nonlinsolve([
                    -Mass * (x ** 2) * y + (k_t - k_e) * y + (k_t3 - k_e3) * (y ** 3) * 3 / 4 - force_ac * np.cos(phi[i]),
                    c * x * y - force_ac * np.sin(phi[i])
                ], [x, y])
                for sol in solutions:
                    if not (np.isreal(sol[0]) and np.isreal(sol[1]) and np.isfinite(float(sol[0])) and np.isfinite(float(sol[1]))):
                        continue
                    if omega_0 / 2 < float(sol[0]) < 3 * omega_0 / 2 and float(sol[0]) > 0:
                        freq[i] = float(sol[0]) / (2 * np.pi)
                        m_c[i] = float(sol[1]) * freq[i] * 2 * np.pi * trans_factor / 1e-9
                        break
            except Exception:
                continue
        results.append({
            'w_t': w_t,
            'l_t': l_t,
            'm_coef_b': m_coef_b,
            'k_coef_b': k_coef_b,
            'k_coef_b3': k_coef_b3,
            'k_tt': k_t,
            'k_t3': k_t3,
            'Mass': Mass,
            'omega_0': omega_0,
            'freq_0': freq_0,
            'trans_factor': trans_factor,
            'k_e': k_e,
            'k_e3': k_e3,
            'freq': freq,
            'm_c': m_c
        })
        count += 1
        print(f"Completed (w_t={w_t*1e6:.2f}um, l_t={l_t*1e6:.2f}um) [{count}/{total}]")

results_df = pd.DataFrame(results)

# 全局常数
constants = dict(
    E=E, rho=rho, t=t, eps_0=eps_0, beta=beta, alpha_n=alpha_n,
    V=V, d=d, electrode_length=electrode_length, electrode_width=electrode_width,
    w_c=w_c, l_c=l_c, Vac_ground=Vac_ground, Q=Q,
    phi=phi, number_of_sim=number_of_sim
)

with pd.HDFStore('./data/wt_lt_big.h5', 'w') as store:
    store['data'] = results_df
    store.get_storer('data').attrs.constants = constants

print("数据生成完成！所有 (w_t, l_t) 响应谱已写入 HDF5 文件。")
# Out:
# Completed (w_t=5.00um, l_t=100.00um) [1/30400]
# Completed (w_t=5.00um, l_t=104.76um) [2/30400]
# Completed (w_t=5.00um, l_t=109.52um) [3/30400]
# Completed (w_t=5.00um, l_t=114.29um) [4/30400]
# Completed (w_t=5.00um, l_t=119.05um) [5/30400]
# Completed (w_t=5.00um, l_t=123.81um) [6/30400]
# Completed (w_t=5.00um, l_t=128.57um) [7/30400]
# Completed (w_t=5.00um, l_t=133.33um) [8/30400]
# Completed (w_t=5.00um, l_t=138.10um) [9/30400]
# Completed (w_t=5.00um, l_t=142.86um) [10/30400]
# Completed (w_t=5.00um, l_t=147.62um) [11/30400]
# Completed (w_t=5.00um, l_t=152.38um) [12/30400]
# Completed (w_t=5.00um, l_t=157.14um) [13/30400]
# Completed (w_t=5.00um, l_t=161.90um) [14/30400]
# Completed (w_t=5.00um, l_t=166.67um) [15/30400]
# Completed (w_t=5.00um, l_t=171.43um) [16/30400]
# Completed (w_t=5.00um, l_t=176.19um) [17/30400]
# Completed (w_t=5.00um, l_t=180.95um) [18/30400]
# Completed (w_t=5.00um, l_t=185.71um) [19/30400]
# Completed (w_t=5.00um, l_t=190.48um) [20/30400]
# Completed (w_t=5.00um, l_t=195.24um) [21/30400]
# Completed (w_t=5.00um, l_t=200.00um) [22/30400]
# Completed (w_t=5.00um, l_t=204.76um) [23/30400]
# Completed (w_t=5.00um, l_t=209.52um) [24/30400]
# Completed (w_t=5.00um, l_t=214.29um) [25/30400]
# Completed (w_t=5.00um, l_t=219.05um) [26/30400]
# Completed (w_t=5.00um, l_t=223.81um) [27/30400]
# Completed (w_t=5.00um, l_t=228.57um) [28/30400]
# Completed (w_t=5.00um, l_t=233.33um) [29/30400]
# Completed (w_t=5.00um, l_t=238.10um) [30/30400]
# Completed (w_t=5.00um, l_t=242.86um) [31/30400]
# Completed (w_t=5.00um, l_t=247.62um) [32/30400]
# Completed (w_t=5.00um, l_t=252.38um) [33/30400]
# Completed (w_t=5.00um, l_t=257.14um) [34/30400]
# Completed (w_t=5.00um, l_t=261.90um) [35/30400]
# Completed (w_t=5.00um, l_t=266.67um) [36/30400]
# Completed (w_t=5.00um, l_t=271.43um) [37/30400]
# Completed (w_t=5.00um, l_t=276.19um) [38/30400]
# Completed (w_t=5.00um, l_t=280.95um) [39/30400]
# Completed (w_t=5.00um, l_t=285.71um) [40/30400]
# Completed (w_t=5.00um, l_t=290.48um) [41/30400]
# Completed (w_t=5.00um, l_t=295.24um) [42/30400]
# Completed (w_t=5.00um, l_t=300.00um) [43/30400]
# Completed (w_t=5.00um, l_t=304.76um) [44/30400]
# Completed (w_t=5.00um, l_t=309.52um) [45/30400]
# Completed (w_t=5.00um, l_t=314.29um) [46/30400]
# Completed (w_t=5.00um, l_t=319.05um) [47/30400]
# Completed (w_t=5.00um, l_t=323.81um) [48/30400]
# Completed (w_t=5.00um, l_t=328.57um) [49/30400]
# Completed (w_t=5.00um, l_t=333.33um) [50/30400]
# Completed (w_t=5.00um, l_t=338.10um) [51/30400]
# Completed (w_t=5.00um, l_t=342.86um) [52/30400]
# Completed (w_t=5.00um, l_t=347.62um) [53/30400]
# Completed (w_t=5.00um, l_t=352.38um) [54/30400]
# Completed (w_t=5.00um, l_t=357.14um) [55/30400]
# Completed (w_t=5.00um, l_t=361.90um) [56/30400]
# Completed (w_t=5.00um, l_t=366.67um) [57/30400]
# Completed (w_t=5.00um, l_t=371.43um) [58/30400]
# Completed (w_t=5.00um, l_t=376.19um) [59/30400]
# Completed (w_t=5.00um, l_t=380.95um) [60/30400]
# Completed (w_t=5.00um, l_t=385.71um) [61/30400]
# Completed (w_t=5.00um, l_t=390.48um) [62/30400]
# Completed (w_t=5.00um, l_t=395.24um) [63/30400]
# Completed (w_t=5.00um, l_t=400.00um) [64/30400]
# Completed (w_t=5.00um, l_t=404.76um) [65/30400]
# Completed (w_t=5.00um, l_t=409.52um) [66/30400]
# Completed (w_t=5.00um, l_t=414.29um) [67/30400]
# Completed (w_t=5.00um, l_t=419.05um) [68/30400]
# Completed (w_t=5.00um, l_t=423.81um) [69/30400]
# Completed (w_t=5.00um, l_t=428.57um) [70/30400]
# Completed (w_t=5.00um, l_t=433.33um) [71/30400]
# Completed (w_t=5.00um, l_t=438.10um) [72/30400]
# Completed (w_t=5.00um, l_t=442.86um) [73/30400]
# Completed (w_t=5.00um, l_t=447.62um) [74/30400]
# Completed (w_t=5.00um, l_t=452.38um) [75/30400]
# Completed (w_t=5.00um, l_t=457.14um) [76/30400]
# Completed (w_t=5.00um, l_t=461.90um) [77/30400]
# Completed (w_t=5.00um, l_t=466.67um) [78/30400]
# Completed (w_t=5.00um, l_t=471.43um) [79/30400]
# Completed (w_t=5.00um, l_t=476.19um) [80/30400]
# Completed (w_t=5.00um, l_t=480.95um) [81/30400]
# Completed (w_t=5.00um, l_t=485.71um) [82/30400]
# Completed (w_t=5.00um, l_t=490.48um) [83/30400]
# Completed (w_t=5.00um, l_t=495.24um) [84/30400]
# Completed (w_t=5.00um, l_t=500.00um) [85/30400]
# Completed (w_t=5.00um, l_t=504.76um) [86/30400]
# Completed (w_t=5.00um, l_t=509.52um) [87/30400]
# Completed (w_t=5.00um, l_t=514.29um) [88/30400]
# Completed (w_t=5.00um, l_t=519.05um) [89/30400]
# Completed (w_t=5.00um, l_t=523.81um) [90/30400]
# Completed (w_t=5.00um, l_t=528.57um) [91/30400]
# Completed (w_t=5.00um, l_t=533.33um) [92/30400]
# Completed (w_t=5.00um, l_t=538.10um) [93/30400]
# Completed (w_t=5.00um, l_t=542.86um) [94/30400]
# Completed (w_t=5.00um, l_t=547.62um) [95/30400]
# Completed (w_t=5.00um, l_t=552.38um) [96/30400]
# Completed (w_t=5.00um, l_t=557.14um) [97/30400]
# Completed (w_t=5.00um, l_t=561.90um) [98/30400]
# Completed (w_t=5.00um, l_t=566.67um) [99/30400]
# Completed (w_t=5.00um, l_t=571.43um) [100/30400]
# Completed (w_t=5.00um, l_t=576.19um) [101/30400]
# Completed (w_t=5.00um, l_t=580.95um) [102/30400]
# Completed (w_t=5.00um, l_t=585.71um) [103/30400]
# Completed (w_t=5.00um, l_t=590.48um) [104/30400]
# Completed (w_t=5.00um, l_t=595.24um) [105/30400]
# Completed (w_t=5.00um, l_t=600.00um) [106/30400]
# Completed (w_t=5.00um, l_t=604.76um) [107/30400]
# Completed (w_t=5.00um, l_t=609.52um) [108/30400]
# Completed (w_t=5.00um, l_t=614.29um) [109/30400]
# Completed (w_t=5.00um, l_t=619.05um) [110/30400]
# Completed (w_t=5.00um, l_t=623.81um) [111/30400]
# Completed (w_t=5.00um, l_t=628.57um) [112/30400]
# Completed (w_t=5.00um, l_t=633.33um) [113/30400]
# Completed (w_t=5.00um, l_t=638.10um) [114/30400]
# Completed (w_t=5.00um, l_t=642.86um) [115/30400]
# Completed (w_t=5.00um, l_t=647.62um) [116/30400]
# Completed (w_t=5.00um, l_t=652.38um) [117/30400]
# Completed (w_t=5.00um, l_t=657.14um) [118/30400]
# Completed (w_t=5.00um, l_t=661.90um) [119/30400]
# Completed (w_t=5.00um, l_t=666.67um) [120/30400]
# Completed (w_t=5.00um, l_t=671.43um) [121/30400]
# Completed (w_t=5.00um, l_t=676.19um) [122/30400]
# Completed (w_t=5.00um, l_t=680.95um) [123/30400]
# Completed (w_t=5.00um, l_t=685.71um) [124/30400]
# Completed (w_t=5.00um, l_t=690.48um) [125/30400]
# Completed (w_t=5.00um, l_t=695.24um) [126/30400]
# Completed (w_t=5.00um, l_t=700.00um) [127/30400]
# Completed (w_t=5.00um, l_t=704.76um) [128/30400]
# Completed (w_t=5.00um, l_t=709.52um) [129/30400]
# Completed (w_t=5.00um, l_t=714.29um) [130/30400]
# Completed (w_t=5.00um, l_t=719.05um) [131/30400]
# Completed (w_t=5.00um, l_t=723.81um) [132/30400]
# Completed (w_t=5.00um, l_t=728.57um) [133/30400]
# Completed (w_t=5.00um, l_t=733.33um) [134/30400]
# Completed (w_t=5.00um, l_t=738.10um) [135/30400]
# Completed (w_t=5.00um, l_t=742.86um) [136/30400]
# Completed (w_t=5.00um, l_t=747.62um) [137/30400]
# Completed (w_t=5.00um, l_t=752.38um) [138/30400]
# Completed (w_t=5.00um, l_t=757.14um) [139/30400]
# Completed (w_t=5.00um, l_t=761.90um) [140/30400]
# Completed (w_t=5.00um, l_t=766.67um) [141/30400]
# Completed (w_t=5.00um, l_t=771.43um) [142/30400]
# Completed (w_t=5.00um, l_t=776.19um) [143/30400]
# Completed (w_t=5.00um, l_t=780.95um) [144/30400]
# Completed (w_t=5.00um, l_t=785.71um) [145/30400]
# Completed (w_t=5.00um, l_t=790.48um) [146/30400]
# Completed (w_t=5.00um, l_t=795.24um) [147/30400]
# Completed (w_t=5.00um, l_t=800.00um) [148/30400]
# Completed (w_t=5.00um, l_t=804.76um) [149/30400]
# Completed (w_t=5.00um, l_t=809.52um) [150/30400]
# Completed (w_t=5.00um, l_t=814.29um) [151/30400]
# Completed (w_t=5.00um, l_t=819.05um) [152/30400]
# Completed (w_t=5.00um, l_t=823.81um) [153/30400]
# Completed (w_t=5.00um, l_t=828.57um) [154/30400]
# Completed (w_t=5.00um, l_t=833.33um) [155/30400]
# Completed (w_t=5.00um, l_t=838.10um) [156/30400]
# Completed (w_t=5.00um, l_t=842.86um) [157/30400]
# Completed (w_t=5.00um, l_t=847.62um) [158/30400]
# Completed (w_t=5.00um, l_t=852.38um) [159/30400]
# Completed (w_t=5.00um, l_t=857.14um) [160/30400]
# Completed (w_t=5.00um, l_t=861.90um) [161/30400]
# Completed (w_t=5.00um, l_t=866.67um) [162/30400]
# Completed (w_t=5.00um, l_t=871.43um) [163/30400]
# Completed (w_t=5.00um, l_t=876.19um) [164/30400]
# Completed (w_t=5.00um, l_t=880.95um) [165/30400]
# Completed (w_t=5.00um, l_t=885.71um) [166/30400]
# Completed (w_t=5.00um, l_t=890.48um) [167/30400]
# Completed (w_t=5.00um, l_t=895.24um) [168/30400]
# Completed (w_t=5.00um, l_t=900.00um) [169/30400]
# Completed (w_t=5.00um, l_t=904.76um) [170/30400]
# Completed (w_t=5.00um, l_t=909.52um) [171/30400]
# Completed (w_t=5.00um, l_t=914.29um) [172/30400]
# Completed (w_t=5.00um, l_t=919.05um) [173/30400]
# Completed (w_t=5.00um, l_t=923.81um) [174/30400]
# Completed (w_t=5.00um, l_t=928.57um) [175/30400]
# Completed (w_t=5.00um, l_t=933.33um) [176/30400]
# Completed (w_t=5.00um, l_t=938.10um) [177/30400]
# Completed (w_t=5.00um, l_t=942.86um) [178/30400]
# Completed (w_t=5.00um, l_t=947.62um) [179/30400]
# Completed (w_t=5.00um, l_t=952.38um) [180/30400]
# Completed (w_t=5.00um, l_t=957.14um) [181/30400]
# Completed (w_t=5.00um, l_t=961.90um) [182/30400]
# Completed (w_t=5.00um, l_t=966.67um) [183/30400]
# Completed (w_t=5.00um, l_t=971.43um) [184/30400]
# Completed (w_t=5.00um, l_t=976.19um) [185/30400]
# Completed (w_t=5.00um, l_t=980.95um) [186/30400]
# Completed (w_t=5.00um, l_t=985.71um) [187/30400]
# Completed (w_t=5.00um, l_t=990.48um) [188/30400]
# Completed (w_t=5.00um, l_t=995.24um) [189/30400]
# Completed (w_t=5.00um, l_t=1000.00um) [190/30400]
# Completed (w_t=5.09um, l_t=100.00um) [191/30400]
# Completed (w_t=5.09um, l_t=104.76um) [192/30400]
# Completed (w_t=5.09um, l_t=109.52um) [193/30400]
# Completed (w_t=5.09um, l_t=114.29um) [194/30400]
# Completed (w_t=5.09um, l_t=119.05um) [195/30400]
# Completed (w_t=5.09um, l_t=123.81um) [196/30400]
# Completed (w_t=5.09um, l_t=128.57um) [197/30400]
# Completed (w_t=5.09um, l_t=133.33um) [198/30400]
# Completed (w_t=5.09um, l_t=138.10um) [199/30400]
# Completed (w_t=5.09um, l_t=142.86um) [200/30400]
# Completed (w_t=5.09um, l_t=147.62um) [201/30400]
# Completed (w_t=5.09um, l_t=152.38um) [202/30400]
# Completed (w_t=5.09um, l_t=157.14um) [203/30400]
# Completed (w_t=5.09um, l_t=161.90um) [204/30400]
# Completed (w_t=5.09um, l_t=166.67um) [205/30400]
# Completed (w_t=5.09um, l_t=171.43um) [206/30400]
# Completed (w_t=5.09um, l_t=176.19um) [207/30400]
# Completed (w_t=5.09um, l_t=180.95um) [208/30400]
# Completed (w_t=5.09um, l_t=185.71um) [209/30400]
# Completed (w_t=5.09um, l_t=190.48um) [210/30400]
# Completed (w_t=5.09um, l_t=195.24um) [211/30400]
# Completed (w_t=5.09um, l_t=200.00um) [212/30400]
# Completed (w_t=5.09um, l_t=204.76um) [213/30400]
# Completed (w_t=5.09um, l_t=209.52um) [214/30400]
# Completed (w_t=5.09um, l_t=214.29um) [215/30400]
# Completed (w_t=5.09um, l_t=219.05um) [216/30400]
# Completed (w_t=5.09um, l_t=223.81um) [217/30400]
# Completed (w_t=5.09um, l_t=228.57um) [218/30400]
# Completed (w_t=5.09um, l_t=233.33um) [219/30400]
# Completed (w_t=5.09um, l_t=238.10um) [220/30400]
# Completed (w_t=5.09um, l_t=242.86um) [221/30400]
# Completed (w_t=5.09um, l_t=247.62um) [222/30400]
# Completed (w_t=5.09um, l_t=252.38um) [223/30400]
# Completed (w_t=5.09um, l_t=257.14um) [224/30400]
# Completed (w_t=5.09um, l_t=261.90um) [225/30400]
# Completed (w_t=5.09um, l_t=266.67um) [226/30400]
# Completed (w_t=5.09um, l_t=271.43um) [227/30400]
# Completed (w_t=5.09um, l_t=276.19um) [228/30400]
# Completed (w_t=5.09um, l_t=280.95um) [229/30400]
# Completed (w_t=5.09um, l_t=285.71um) [230/30400]
# Completed (w_t=5.09um, l_t=290.48um) [231/30400]
# Completed (w_t=5.09um, l_t=295.24um) [232/30400]
# Completed (w_t=5.09um, l_t=300.00um) [233/30400]
# Completed (w_t=5.09um, l_t=304.76um) [234/30400]
# Completed (w_t=5.09um, l_t=309.52um) [235/30400]
# Completed (w_t=5.09um, l_t=314.29um) [236/30400]
# Completed (w_t=5.09um, l_t=319.05um) [237/30400]
# Completed (w_t=5.09um, l_t=323.81um) [238/30400]
# Completed (w_t=5.09um, l_t=328.57um) [239/30400]
# Completed (w_t=5.09um, l_t=333.33um) [240/30400]
# Completed (w_t=5.09um, l_t=338.10um) [241/30400]
# Completed (w_t=5.09um, l_t=342.86um) [242/30400]
# Completed (w_t=5.09um, l_t=347.62um) [243/30400]
# Completed (w_t=5.09um, l_t=352.38um) [244/30400]
# Completed (w_t=5.09um, l_t=357.14um) [245/30400]
# Completed (w_t=5.09um, l_t=361.90um) [246/30400]
# Completed (w_t=5.09um, l_t=366.67um) [247/30400]
# Completed (w_t=5.09um, l_t=371.43um) [248/30400]
# Completed (w_t=5.09um, l_t=376.19um) [249/30400]
# Completed (w_t=5.09um, l_t=380.95um) [250/30400]
# Completed (w_t=5.09um, l_t=385.71um) [251/30400]
# Completed (w_t=5.09um, l_t=390.48um) [252/30400]
# Completed (w_t=5.09um, l_t=395.24um) [253/30400]
# Completed (w_t=5.09um, l_t=400.00um) [254/30400]
# Completed (w_t=5.09um, l_t=404.76um) [255/30400]
# Completed (w_t=5.09um, l_t=409.52um) [256/30400]
# Completed (w_t=5.09um, l_t=414.29um) [257/30400]
# Completed (w_t=5.09um, l_t=419.05um) [258/30400]
# Completed (w_t=5.09um, l_t=423.81um) [259/30400]
# Completed (w_t=5.09um, l_t=428.57um) [260/30400]
# Completed (w_t=5.09um, l_t=433.33um) [261/30400]
# Completed (w_t=5.09um, l_t=438.10um) [262/30400]
# Completed (w_t=5.09um, l_t=442.86um) [263/30400]
# Completed (w_t=5.09um, l_t=447.62um) [264/30400]
# Completed (w_t=5.09um, l_t=452.38um) [265/30400]
# Completed (w_t=5.09um, l_t=457.14um) [266/30400]
# Completed (w_t=5.09um, l_t=461.90um) [267/30400]
# Completed (w_t=5.09um, l_t=466.67um) [268/30400]
# Completed (w_t=5.09um, l_t=471.43um) [269/30400]
# Completed (w_t=5.09um, l_t=476.19um) [270/30400]
# Completed (w_t=5.09um, l_t=480.95um) [271/30400]
# Completed (w_t=5.09um, l_t=485.71um) [272/30400]
# Completed (w_t=5.09um, l_t=490.48um) [273/30400]
# Completed (w_t=5.09um, l_t=495.24um) [274/30400]
# Completed (w_t=5.09um, l_t=500.00um) [275/30400]
# Completed (w_t=5.09um, l_t=504.76um) [276/30400]
# Completed (w_t=5.09um, l_t=509.52um) [277/30400]
# Completed (w_t=5.09um, l_t=514.29um) [278/30400]
# Completed (w_t=5.09um, l_t=519.05um) [279/30400]
# Completed (w_t=5.09um, l_t=523.81um) [280/30400]
# Completed (w_t=5.09um, l_t=528.57um) [281/30400]
# Completed (w_t=5.09um, l_t=533.33um) [282/30400]
# Completed (w_t=5.09um, l_t=538.10um) [283/30400]
# Completed (w_t=5.09um, l_t=542.86um) [284/30400]
# Completed (w_t=5.09um, l_t=547.62um) [285/30400]
# Completed (w_t=5.09um, l_t=552.38um) [286/30400]
# Completed (w_t=5.09um, l_t=557.14um) [287/30400]
# Completed (w_t=5.09um, l_t=561.90um) [288/30400]
# Completed (w_t=5.09um, l_t=566.67um) [289/30400]
# Completed (w_t=5.09um, l_t=571.43um) [290/30400]
# Completed (w_t=5.09um, l_t=576.19um) [291/30400]
# Completed (w_t=5.09um, l_t=580.95um) [292/30400]
# Completed (w_t=5.09um, l_t=585.71um) [293/30400]
# Completed (w_t=5.09um, l_t=590.48um) [294/30400]
# Completed (w_t=5.09um, l_t=595.24um) [295/30400]
# Completed (w_t=5.09um, l_t=600.00um) [296/30400]
# Completed (w_t=5.09um, l_t=604.76um) [297/30400]
# Completed (w_t=5.09um, l_t=609.52um) [298/30400]
# Completed (w_t=5.09um, l_t=614.29um) [299/30400]
# Completed (w_t=5.09um, l_t=619.05um) [300/30400]
# Completed (w_t=5.09um, l_t=623.81um) [301/30400]
# Completed (w_t=5.09um, l_t=628.57um) [302/30400]
# Completed (w_t=5.09um, l_t=633.33um) [303/30400]
# Completed (w_t=5.09um, l_t=638.10um) [304/30400]
# Completed (w_t=5.09um, l_t=642.86um) [305/30400]
# Completed (w_t=5.09um, l_t=647.62um) [306/30400]
# Completed (w_t=5.09um, l_t=652.38um) [307/30400]
# Completed (w_t=5.09um, l_t=657.14um) [308/30400]
# Completed (w_t=5.09um, l_t=661.90um) [309/30400]
# Completed (w_t=5.09um, l_t=666.67um) [310/30400]
# Completed (w_t=5.09um, l_t=671.43um) [311/30400]
# Completed (w_t=5.09um, l_t=676.19um) [312/30400]
# Completed (w_t=5.09um, l_t=680.95um) [313/30400]
# Completed (w_t=5.09um, l_t=685.71um) [314/30400]
# Completed (w_t=5.09um, l_t=690.48um) [315/30400]
# Completed (w_t=5.09um, l_t=695.24um) [316/30400]
# Completed (w_t=5.09um, l_t=700.00um) [317/30400]
# Completed (w_t=5.09um, l_t=704.76um) [318/30400]
# Completed (w_t=5.09um, l_t=709.52um) [319/30400]
# Completed (w_t=5.09um, l_t=714.29um) [320/30400]
# Completed (w_t=5.09um, l_t=719.05um) [321/30400]
# Completed (w_t=5.09um, l_t=723.81um) [322/30400]
# Completed (w_t=5.09um, l_t=728.57um) [323/30400]
# Completed (w_t=5.09um, l_t=733.33um) [324/30400]
# Completed (w_t=5.09um, l_t=738.10um) [325/30400]
# Completed (w_t=5.09um, l_t=742.86um) [326/30400]
# Completed (w_t=5.09um, l_t=747.62um) [327/30400]
# Completed (w_t=5.09um, l_t=752.38um) [328/30400]
# Completed (w_t=5.09um, l_t=757.14um) [329/30400]
# Completed (w_t=5.09um, l_t=761.90um) [330/30400]
# Completed (w_t=5.09um, l_t=766.67um) [331/30400]
# Completed (w_t=5.09um, l_t=771.43um) [332/30400]
# Completed (w_t=5.09um, l_t=776.19um) [333/30400]
# Completed (w_t=5.09um, l_t=780.95um) [334/30400]
# Completed (w_t=5.09um, l_t=785.71um) [335/30400]
# Completed (w_t=5.09um, l_t=790.48um) [336/30400]
# Completed (w_t=5.09um, l_t=795.24um) [337/30400]
# Completed (w_t=5.09um, l_t=800.00um) [338/30400]
# Completed (w_t=5.09um, l_t=804.76um) [339/30400]
# Completed (w_t=5.09um, l_t=809.52um) [340/30400]
# Completed (w_t=5.09um, l_t=814.29um) [341/30400]
# Completed (w_t=5.09um, l_t=819.05um) [342/30400]
# Completed (w_t=5.09um, l_t=823.81um) [343/30400]
# Completed (w_t=5.09um, l_t=828.57um) [344/30400]
# Completed (w_t=5.09um, l_t=833.33um) [345/30400]
# Completed (w_t=5.09um, l_t=838.10um) [346/30400]
# Completed (w_t=5.09um, l_t=842.86um) [347/30400]
# Completed (w_t=5.09um, l_t=847.62um) [348/30400]
# Completed (w_t=5.09um, l_t=852.38um) [349/30400]
# Completed (w_t=5.09um, l_t=857.14um) [350/30400]
# Completed (w_t=5.09um, l_t=861.90um) [351/30400]
# Completed (w_t=5.09um, l_t=866.67um) [352/30400]
# Completed (w_t=5.09um, l_t=871.43um) [353/30400]
# Completed (w_t=5.09um, l_t=876.19um) [354/30400]
# Completed (w_t=5.09um, l_t=880.95um) [355/30400]
# Completed (w_t=5.09um, l_t=885.71um) [356/30400]
# Completed (w_t=5.09um, l_t=890.48um) [357/30400]
# Completed (w_t=5.09um, l_t=895.24um) [358/30400]
# Completed (w_t=5.09um, l_t=900.00um) [359/30400]
# Completed (w_t=5.09um, l_t=904.76um) [360/30400]
# Completed (w_t=5.09um, l_t=909.52um) [361/30400]
# Completed (w_t=5.09um, l_t=914.29um) [362/30400]
# Completed (w_t=5.09um, l_t=919.05um) [363/30400]
# Completed (w_t=5.09um, l_t=923.81um) [364/30400]
# Completed (w_t=5.09um, l_t=928.57um) [365/30400]
# Completed (w_t=5.09um, l_t=933.33um) [366/30400]
# Completed (w_t=5.09um, l_t=938.10um) [367/30400]
# Completed (w_t=5.09um, l_t=942.86um) [368/30400]
# Completed (w_t=5.09um, l_t=947.62um) [369/30400]
# Completed (w_t=5.09um, l_t=952.38um) [370/30400]
# Completed (w_t=5.09um, l_t=957.14um) [371/30400]
# Completed (w_t=5.09um, l_t=961.90um) [372/30400]
# Completed (w_t=5.09um, l_t=966.67um) [373/30400]
# Completed (w_t=5.09um, l_t=971.43um) [374/30400]
# Completed (w_t=5.09um, l_t=976.19um) [375/30400]
# Completed (w_t=5.09um, l_t=980.95um) [376/30400]
# Completed (w_t=5.09um, l_t=985.71um) [377/30400]
# Completed (w_t=5.09um, l_t=990.48um) [378/30400]
# Completed (w_t=5.09um, l_t=995.24um) [379/30400]
# Completed (w_t=5.09um, l_t=1000.00um) [380/30400]
# Completed (w_t=5.19um, l_t=100.00um) [381/30400]
# Completed (w_t=5.19um, l_t=104.76um) [382/30400]
# Completed (w_t=5.19um, l_t=109.52um) [383/30400]
# Completed (w_t=5.19um, l_t=114.29um) [384/30400]
# Completed (w_t=5.19um, l_t=119.05um) [385/30400]
# Completed (w_t=5.19um, l_t=123.81um) [386/30400]
# Completed (w_t=5.19um, l_t=128.57um) [387/30400]
# Completed (w_t=5.19um, l_t=133.33um) [388/30400]
# Completed (w_t=5.19um, l_t=138.10um) [389/30400]
# Completed (w_t=5.19um, l_t=142.86um) [390/30400]
# Completed (w_t=5.19um, l_t=147.62um) [391/30400]
# Completed (w_t=5.19um, l_t=152.38um) [392/30400]
# Completed (w_t=5.19um, l_t=157.14um) [393/30400]
# Completed (w_t=5.19um, l_t=161.90um) [394/30400]
# Completed (w_t=5.19um, l_t=166.67um) [395/30400]
# Completed (w_t=5.19um, l_t=171.43um) [396/30400]
# Completed (w_t=5.19um, l_t=176.19um) [397/30400]
# Completed (w_t=5.19um, l_t=180.95um) [398/30400]
# Completed (w_t=5.19um, l_t=185.71um) [399/30400]
# Completed (w_t=5.19um, l_t=190.48um) [400/30400]
# Completed (w_t=5.19um, l_t=195.24um) [401/30400]
# Completed (w_t=5.19um, l_t=200.00um) [402/30400]
# Completed (w_t=5.19um, l_t=204.76um) [403/30400]
# Completed (w_t=5.19um, l_t=209.52um) [404/30400]
# Completed (w_t=5.19um, l_t=214.29um) [405/30400]
# Completed (w_t=5.19um, l_t=219.05um) [406/30400]
# Completed (w_t=5.19um, l_t=223.81um) [407/30400]
# Completed (w_t=5.19um, l_t=228.57um) [408/30400]
# Completed (w_t=5.19um, l_t=233.33um) [409/30400]
# Completed (w_t=5.19um, l_t=238.10um) [410/30400]
# Completed (w_t=5.19um, l_t=242.86um) [411/30400]
# Completed (w_t=5.19um, l_t=247.62um) [412/30400]
# Completed (w_t=5.19um, l_t=252.38um) [413/30400]
# Completed (w_t=5.19um, l_t=257.14um) [414/30400]
# Completed (w_t=5.19um, l_t=261.90um) [415/30400]
# Completed (w_t=5.19um, l_t=266.67um) [416/30400]
# Completed (w_t=5.19um, l_t=271.43um) [417/30400]
# Completed (w_t=5.19um, l_t=276.19um) [418/30400]
# Completed (w_t=5.19um, l_t=280.95um) [419/30400]
# Completed (w_t=5.19um, l_t=285.71um) [420/30400]
# Completed (w_t=5.19um, l_t=290.48um) [421/30400]
# Completed (w_t=5.19um, l_t=295.24um) [422/30400]
# Completed (w_t=5.19um, l_t=300.00um) [423/30400]
# Completed (w_t=5.19um, l_t=304.76um) [424/30400]
# Completed (w_t=5.19um, l_t=309.52um) [425/30400]
# Completed (w_t=5.19um, l_t=314.29um) [426/30400]
# Completed (w_t=5.19um, l_t=319.05um) [427/30400]
# Completed (w_t=5.19um, l_t=323.81um) [428/30400]
# Completed (w_t=5.19um, l_t=328.57um) [429/30400]
# Completed (w_t=5.19um, l_t=333.33um) [430/30400]
# Completed (w_t=5.19um, l_t=338.10um) [431/30400]
# Completed (w_t=5.19um, l_t=342.86um) [432/30400]
# Completed (w_t=5.19um, l_t=347.62um) [433/30400]
# Completed (w_t=5.19um, l_t=352.38um) [434/30400]
# Completed (w_t=5.19um, l_t=357.14um) [435/30400]
# Completed (w_t=5.19um, l_t=361.90um) [436/30400]
# Completed (w_t=5.19um, l_t=366.67um) [437/30400]
# Completed (w_t=5.19um, l_t=371.43um) [438/30400]
# Completed (w_t=5.19um, l_t=376.19um) [439/30400]
# Completed (w_t=5.19um, l_t=380.95um) [440/30400]
# Completed (w_t=5.19um, l_t=385.71um) [441/30400]
# Completed (w_t=5.19um, l_t=390.48um) [442/30400]
# Completed (w_t=5.19um, l_t=395.24um) [443/30400]
# Completed (w_t=5.19um, l_t=400.00um) [444/30400]
# Completed (w_t=5.19um, l_t=404.76um) [445/30400]
# Completed (w_t=5.19um, l_t=409.52um) [446/30400]
# Completed (w_t=5.19um, l_t=414.29um) [447/30400]
# Completed (w_t=5.19um, l_t=419.05um) [448/30400]
# Completed (w_t=5.19um, l_t=423.81um) [449/30400]
# Completed (w_t=5.19um, l_t=428.57um) [450/30400]
# Completed (w_t=5.19um, l_t=433.33um) [451/30400]
# Completed (w_t=5.19um, l_t=438.10um) [452/30400]
# Completed (w_t=5.19um, l_t=442.86um) [453/30400]
# Completed (w_t=5.19um, l_t=447.62um) [454/30400]
# Completed (w_t=5.19um, l_t=452.38um) [455/30400]
# Completed (w_t=5.19um, l_t=457.14um) [456/30400]
# Completed (w_t=5.19um, l_t=461.90um) [457/30400]
# Completed (w_t=5.19um, l_t=466.67um) [458/30400]
# Completed (w_t=5.19um, l_t=471.43um) [459/30400]
# Completed (w_t=5.19um, l_t=476.19um) [460/30400]
# Completed (w_t=5.19um, l_t=480.95um) [461/30400]
# Completed (w_t=5.19um, l_t=485.71um) [462/30400]
# Completed (w_t=5.19um, l_t=490.48um) [463/30400]
# Completed (w_t=5.19um, l_t=495.24um) [464/30400]
# Completed (w_t=5.19um, l_t=500.00um) [465/30400]
# Completed (w_t=5.19um, l_t=504.76um) [466/30400]
# Completed (w_t=5.19um, l_t=509.52um) [467/30400]
# Completed (w_t=5.19um, l_t=514.29um) [468/30400]
# Completed (w_t=5.19um, l_t=519.05um) [469/30400]
# Completed (w_t=5.19um, l_t=523.81um) [470/30400]
# Completed (w_t=5.19um, l_t=528.57um) [471/30400]
# Completed (w_t=5.19um, l_t=533.33um) [472/30400]
# Completed (w_t=5.19um, l_t=538.10um) [473/30400]
# Completed (w_t=5.19um, l_t=542.86um) [474/30400]
# Completed (w_t=5.19um, l_t=547.62um) [475/30400]
# Completed (w_t=5.19um, l_t=552.38um) [476/30400]
# Completed (w_t=5.19um, l_t=557.14um) [477/30400]
# Completed (w_t=5.19um, l_t=561.90um) [478/30400]
# Completed (w_t=5.19um, l_t=566.67um) [479/30400]
# Completed (w_t=5.19um, l_t=571.43um) [480/30400]
# Completed (w_t=5.19um, l_t=576.19um) [481/30400]
# Completed (w_t=5.19um, l_t=580.95um) [482/30400]
# Completed (w_t=5.19um, l_t=585.71um) [483/30400]
# Completed (w_t=5.19um, l_t=590.48um) [484/30400]
# Completed (w_t=5.19um, l_t=595.24um) [485/30400]
# Completed (w_t=5.19um, l_t=600.00um) [486/30400]
# Completed (w_t=5.19um, l_t=604.76um) [487/30400]
# Completed (w_t=5.19um, l_t=609.52um) [488/30400]
# Completed (w_t=5.19um, l_t=614.29um) [489/30400]
# Completed (w_t=5.19um, l_t=619.05um) [490/30400]
# Completed (w_t=5.19um, l_t=623.81um) [491/30400]
# Completed (w_t=5.19um, l_t=628.57um) [492/30400]
# Completed (w_t=5.19um, l_t=633.33um) [493/30400]
# Completed (w_t=5.19um, l_t=638.10um) [494/30400]
# Completed (w_t=5.19um, l_t=642.86um) [495/30400]
# Completed (w_t=5.19um, l_t=647.62um) [496/30400]
# Completed (w_t=5.19um, l_t=652.38um) [497/30400]
# Completed (w_t=5.19um, l_t=657.14um) [498/30400]
# Completed (w_t=5.19um, l_t=661.90um) [499/30400]
# Completed (w_t=5.19um, l_t=666.67um) [500/30400]
# Completed (w_t=5.19um, l_t=671.43um) [501/30400]
# Completed (w_t=5.19um, l_t=676.19um) [502/30400]
# Completed (w_t=5.19um, l_t=680.95um) [503/30400]
# Completed (w_t=5.19um, l_t=685.71um) [504/30400]
# Completed (w_t=5.19um, l_t=690.48um) [505/30400]
# Completed (w_t=5.19um, l_t=695.24um) [506/30400]
# Completed (w_t=5.19um, l_t=700.00um) [507/30400]
# Completed (w_t=5.19um, l_t=704.76um) [508/30400]
# Completed (w_t=5.19um, l_t=709.52um) [509/30400]
# Completed (w_t=5.19um, l_t=714.29um) [510/30400]
# Completed (w_t=5.19um, l_t=719.05um) [511/30400]
# Completed (w_t=5.19um, l_t=723.81um) [512/30400]
# Completed (w_t=5.19um, l_t=728.57um) [513/30400]
# Completed (w_t=5.19um, l_t=733.33um) [514/30400]
# Completed (w_t=5.19um, l_t=738.10um) [515/30400]
# Completed (w_t=5.19um, l_t=742.86um) [516/30400]
# Completed (w_t=5.19um, l_t=747.62um) [517/30400]
# Completed (w_t=5.19um, l_t=752.38um) [518/30400]
# Completed (w_t=5.19um, l_t=757.14um) [519/30400]
# Completed (w_t=5.19um, l_t=761.90um) [520/30400]
# Completed (w_t=5.19um, l_t=766.67um) [521/30400]
# Completed (w_t=5.19um, l_t=771.43um) [522/30400]
# Completed (w_t=5.19um, l_t=776.19um) [523/30400]
# Completed (w_t=5.19um, l_t=780.95um) [524/30400]
# Completed (w_t=5.19um, l_t=785.71um) [525/30400]
# Completed (w_t=5.19um, l_t=790.48um) [526/30400]
# Completed (w_t=5.19um, l_t=795.24um) [527/30400]
# Completed (w_t=5.19um, l_t=800.00um) [528/30400]
# Completed (w_t=5.19um, l_t=804.76um) [529/30400]
# Completed (w_t=5.19um, l_t=809.52um) [530/30400]
# Completed (w_t=5.19um, l_t=814.29um) [531/30400]
# Completed (w_t=5.19um, l_t=819.05um) [532/30400]
# Completed (w_t=5.19um, l_t=823.81um) [533/30400]
# Completed (w_t=5.19um, l_t=828.57um) [534/30400]
# Completed (w_t=5.19um, l_t=833.33um) [535/30400]
# Completed (w_t=5.19um, l_t=838.10um) [536/30400]
# Completed (w_t=5.19um, l_t=842.86um) [537/30400]
# Completed (w_t=5.19um, l_t=847.62um) [538/30400]
# Completed (w_t=5.19um, l_t=852.38um) [539/30400]
# Completed (w_t=5.19um, l_t=857.14um) [540/30400]
# Completed (w_t=5.19um, l_t=861.90um) [541/30400]
# Completed (w_t=5.19um, l_t=866.67um) [542/30400]
# Completed (w_t=5.19um, l_t=871.43um) [543/30400]
# Completed (w_t=5.19um, l_t=876.19um) [544/30400]
# Completed (w_t=5.19um, l_t=880.95um) [545/30400]
# Completed (w_t=5.19um, l_t=885.71um) [546/30400]
# Completed (w_t=5.19um, l_t=890.48um) [547/30400]
# Completed (w_t=5.19um, l_t=895.24um) [548/30400]
# Completed (w_t=5.19um, l_t=900.00um) [549/30400]
# Completed (w_t=5.19um, l_t=904.76um) [550/30400]
# Completed (w_t=5.19um, l_t=909.52um) [551/30400]
# Completed (w_t=5.19um, l_t=914.29um) [552/30400]
# Completed (w_t=5.19um, l_t=919.05um) [553/30400]
# Completed (w_t=5.19um, l_t=923.81um) [554/30400]
# Completed (w_t=5.19um, l_t=928.57um) [555/30400]
# Completed (w_t=5.19um, l_t=933.33um) [556/30400]
# Completed (w_t=5.19um, l_t=938.10um) [557/30400]
# Completed (w_t=5.19um, l_t=942.86um) [558/30400]
# Completed (w_t=5.19um, l_t=947.62um) [559/30400]
# Completed (w_t=5.19um, l_t=952.38um) [560/30400]
# Completed (w_t=5.19um, l_t=957.14um) [561/30400]
# Completed (w_t=5.19um, l_t=961.90um) [562/30400]
# Completed (w_t=5.19um, l_t=966.67um) [563/30400]
# Completed (w_t=5.19um, l_t=971.43um) [564/30400]
# Completed (w_t=5.19um, l_t=976.19um) [565/30400]
# Completed (w_t=5.19um, l_t=980.95um) [566/30400]
# Completed (w_t=5.19um, l_t=985.71um) [567/30400]
# Completed (w_t=5.19um, l_t=990.48um) [568/30400]
# Completed (w_t=5.19um, l_t=995.24um) [569/30400]
# Completed (w_t=5.19um, l_t=1000.00um) [570/30400]
# Completed (w_t=5.28um, l_t=100.00um) [571/30400]
# Completed (w_t=5.28um, l_t=104.76um) [572/30400]
# Completed (w_t=5.28um, l_t=109.52um) [573/30400]
# Completed (w_t=5.28um, l_t=114.29um) [574/30400]
# Completed (w_t=5.28um, l_t=119.05um) [575/30400]
# Completed (w_t=5.28um, l_t=123.81um) [576/30400]
# Completed (w_t=5.28um, l_t=128.57um) [577/30400]
# Completed (w_t=5.28um, l_t=133.33um) [578/30400]
# Completed (w_t=5.28um, l_t=138.10um) [579/30400]
# Completed (w_t=5.28um, l_t=142.86um) [580/30400]
# Completed (w_t=5.28um, l_t=147.62um) [581/30400]
# Completed (w_t=5.28um, l_t=152.38um) [582/30400]
# Completed (w_t=5.28um, l_t=157.14um) [583/30400]
# Completed (w_t=5.28um, l_t=161.90um) [584/30400]
# Completed (w_t=5.28um, l_t=166.67um) [585/30400]
# Completed (w_t=5.28um, l_t=171.43um) [586/30400]
# Completed (w_t=5.28um, l_t=176.19um) [587/30400]
# Completed (w_t=5.28um, l_t=180.95um) [588/30400]
# Completed (w_t=5.28um, l_t=185.71um) [589/30400]
# Completed (w_t=5.28um, l_t=190.48um) [590/30400]
# Completed (w_t=5.28um, l_t=195.24um) [591/30400]
# Completed (w_t=5.28um, l_t=200.00um) [592/30400]
# Completed (w_t=5.28um, l_t=204.76um) [593/30400]
# Completed (w_t=5.28um, l_t=209.52um) [594/30400]
# Completed (w_t=5.28um, l_t=214.29um) [595/30400]
# Completed (w_t=5.28um, l_t=219.05um) [596/30400]
# Completed (w_t=5.28um, l_t=223.81um) [597/30400]
# Completed (w_t=5.28um, l_t=228.57um) [598/30400]
# Completed (w_t=5.28um, l_t=233.33um) [599/30400]
# Completed (w_t=5.28um, l_t=238.10um) [600/30400]
# Completed (w_t=5.28um, l_t=242.86um) [601/30400]
# Completed (w_t=5.28um, l_t=247.62um) [602/30400]
# Completed (w_t=5.28um, l_t=252.38um) [603/30400]
# Completed (w_t=5.28um, l_t=257.14um) [604/30400]
# Completed (w_t=5.28um, l_t=261.90um) [605/30400]
# Completed (w_t=5.28um, l_t=266.67um) [606/30400]
# Completed (w_t=5.28um, l_t=271.43um) [607/30400]
# Completed (w_t=5.28um, l_t=276.19um) [608/30400]
# Completed (w_t=5.28um, l_t=280.95um) [609/30400]
# Completed (w_t=5.28um, l_t=285.71um) [610/30400]
# Completed (w_t=5.28um, l_t=290.48um) [611/30400]
# Completed (w_t=5.28um, l_t=295.24um) [612/30400]
# Completed (w_t=5.28um, l_t=300.00um) [613/30400]
# Completed (w_t=5.28um, l_t=304.76um) [614/30400]
# Completed (w_t=5.28um, l_t=309.52um) [615/30400]
# Completed (w_t=5.28um, l_t=314.29um) [616/30400]
# Completed (w_t=5.28um, l_t=319.05um) [617/30400]
# Completed (w_t=5.28um, l_t=323.81um) [618/30400]
# Completed (w_t=5.28um, l_t=328.57um) [619/30400]
# Completed (w_t=5.28um, l_t=333.33um) [620/30400]
# Completed (w_t=5.28um, l_t=338.10um) [621/30400]
# Completed (w_t=5.28um, l_t=342.86um) [622/30400]
# Completed (w_t=5.28um, l_t=347.62um) [623/30400]
# Completed (w_t=5.28um, l_t=352.38um) [624/30400]
# Completed (w_t=5.28um, l_t=357.14um) [625/30400]
# Completed (w_t=5.28um, l_t=361.90um) [626/30400]
# Completed (w_t=5.28um, l_t=366.67um) [627/30400]
# Completed (w_t=5.28um, l_t=371.43um) [628/30400]
# Completed (w_t=5.28um, l_t=376.19um) [629/30400]
# Completed (w_t=5.28um, l_t=380.95um) [630/30400]
# Completed (w_t=5.28um, l_t=385.71um) [631/30400]
# Completed (w_t=5.28um, l_t=390.48um) [632/30400]
# Completed (w_t=5.28um, l_t=395.24um) [633/30400]
# Completed (w_t=5.28um, l_t=400.00um) [634/30400]
# Completed (w_t=5.28um, l_t=404.76um) [635/30400]
# Completed (w_t=5.28um, l_t=409.52um) [636/30400]
# Completed (w_t=5.28um, l_t=414.29um) [637/30400]
# Completed (w_t=5.28um, l_t=419.05um) [638/30400]
# Completed (w_t=5.28um, l_t=423.81um) [639/30400]
# Completed (w_t=5.28um, l_t=428.57um) [640/30400]
# Completed (w_t=5.28um, l_t=433.33um) [641/30400]
# Completed (w_t=5.28um, l_t=438.10um) [642/30400]
# Completed (w_t=5.28um, l_t=442.86um) [643/30400]
# Completed (w_t=5.28um, l_t=447.62um) [644/30400]
# Completed (w_t=5.28um, l_t=452.38um) [645/30400]
# Completed (w_t=5.28um, l_t=457.14um) [646/30400]
# Completed (w_t=5.28um, l_t=461.90um) [647/30400]
# Completed (w_t=5.28um, l_t=466.67um) [648/30400]
# Completed (w_t=5.28um, l_t=471.43um) [649/30400]
# Completed (w_t=5.28um, l_t=476.19um) [650/30400]
# Completed (w_t=5.28um, l_t=480.95um) [651/30400]
# Completed (w_t=5.28um, l_t=485.71um) [652/30400]
# Completed (w_t=5.28um, l_t=490.48um) [653/30400]
# Completed (w_t=5.28um, l_t=495.24um) [654/30400]
# Completed (w_t=5.28um, l_t=500.00um) [655/30400]
# Completed (w_t=5.28um, l_t=504.76um) [656/30400]
# Completed (w_t=5.28um, l_t=509.52um) [657/30400]
# Completed (w_t=5.28um, l_t=514.29um) [658/30400]
# Completed (w_t=5.28um, l_t=519.05um) [659/30400]
# Completed (w_t=5.28um, l_t=523.81um) [660/30400]
# Completed (w_t=5.28um, l_t=528.57um) [661/30400]
# Completed (w_t=5.28um, l_t=533.33um) [662/30400]
# Completed (w_t=5.28um, l_t=538.10um) [663/30400]
# Completed (w_t=5.28um, l_t=542.86um) [664/30400]
# Completed (w_t=5.28um, l_t=547.62um) [665/30400]
# Completed (w_t=5.28um, l_t=552.38um) [666/30400]
# Completed (w_t=5.28um, l_t=557.14um) [667/30400]
# Completed (w_t=5.28um, l_t=561.90um) [668/30400]
# Completed (w_t=5.28um, l_t=566.67um) [669/30400]
# Completed (w_t=5.28um, l_t=571.43um) [670/30400]
# Completed (w_t=5.28um, l_t=576.19um) [671/30400]
# Completed (w_t=5.28um, l_t=580.95um) [672/30400]
# Completed (w_t=5.28um, l_t=585.71um) [673/30400]
# Completed (w_t=5.28um, l_t=590.48um) [674/30400]
# Completed (w_t=5.28um, l_t=595.24um) [675/30400]
# Completed (w_t=5.28um, l_t=600.00um) [676/30400]
# Completed (w_t=5.28um, l_t=604.76um) [677/30400]
# Completed (w_t=5.28um, l_t=609.52um) [678/30400]
# Completed (w_t=5.28um, l_t=614.29um) [679/30400]
# Completed (w_t=5.28um, l_t=619.05um) [680/30400]
# Completed (w_t=5.28um, l_t=623.81um) [681/30400]
# Completed (w_t=5.28um, l_t=628.57um) [682/30400]
# Completed (w_t=5.28um, l_t=633.33um) [683/30400]
# Completed (w_t=5.28um, l_t=638.10um) [684/30400]
# Completed (w_t=5.28um, l_t=642.86um) [685/30400]
# Completed (w_t=5.28um, l_t=647.62um) [686/30400]
# Completed (w_t=5.28um, l_t=652.38um) [687/30400]
# Completed (w_t=5.28um, l_t=657.14um) [688/30400]
# Completed (w_t=5.28um, l_t=661.90um) [689/30400]
# Completed (w_t=5.28um, l_t=666.67um) [690/30400]
# Completed (w_t=5.28um, l_t=671.43um) [691/30400]
# Completed (w_t=5.28um, l_t=676.19um) [692/30400]
# Completed (w_t=5.28um, l_t=680.95um) [693/30400]
# Completed (w_t=5.28um, l_t=685.71um) [694/30400]
# Completed (w_t=5.28um, l_t=690.48um) [695/30400]
# Completed (w_t=5.28um, l_t=695.24um) [696/30400]
# Completed (w_t=5.28um, l_t=700.00um) [697/30400]
# Completed (w_t=5.28um, l_t=704.76um) [698/30400]
# Completed (w_t=5.28um, l_t=709.52um) [699/30400]
# Completed (w_t=5.28um, l_t=714.29um) [700/30400]
# Completed (w_t=5.28um, l_t=719.05um) [701/30400]
# Completed (w_t=5.28um, l_t=723.81um) [702/30400]
# Completed (w_t=5.28um, l_t=728.57um) [703/30400]
# Completed (w_t=5.28um, l_t=733.33um) [704/30400]
# Completed (w_t=5.28um, l_t=738.10um) [705/30400]
# Completed (w_t=5.28um, l_t=742.86um) [706/30400]
# Completed (w_t=5.28um, l_t=747.62um) [707/30400]
# Completed (w_t=5.28um, l_t=752.38um) [708/30400]
# Completed (w_t=5.28um, l_t=757.14um) [709/30400]
# Completed (w_t=5.28um, l_t=761.90um) [710/30400]
# Completed (w_t=5.28um, l_t=766.67um) [711/30400]
# Completed (w_t=5.28um, l_t=771.43um) [712/30400]
# Completed (w_t=5.28um, l_t=776.19um) [713/30400]
# Completed (w_t=5.28um, l_t=780.95um) [714/30400]
# Completed (w_t=5.28um, l_t=785.71um) [715/30400]
# Completed (w_t=5.28um, l_t=790.48um) [716/30400]
# Completed (w_t=5.28um, l_t=795.24um) [717/30400]
# Completed (w_t=5.28um, l_t=800.00um) [718/30400]
# Completed (w_t=5.28um, l_t=804.76um) [719/30400]
# Completed (w_t=5.28um, l_t=809.52um) [720/30400]
# Completed (w_t=5.28um, l_t=814.29um) [721/30400]
# Completed (w_t=5.28um, l_t=819.05um) [722/30400]
# Completed (w_t=5.28um, l_t=823.81um) [723/30400]
# Completed (w_t=5.28um, l_t=828.57um) [724/30400]
# Completed (w_t=5.28um, l_t=833.33um) [725/30400]
# Completed (w_t=5.28um, l_t=838.10um) [726/30400]
# Completed (w_t=5.28um, l_t=842.86um) [727/30400]
# Completed (w_t=5.28um, l_t=847.62um) [728/30400]
# Completed (w_t=5.28um, l_t=852.38um) [729/30400]
# Completed (w_t=5.28um, l_t=857.14um) [730/30400]
# Completed (w_t=5.28um, l_t=861.90um) [731/30400]
# Completed (w_t=5.28um, l_t=866.67um) [732/30400]
# Completed (w_t=5.28um, l_t=871.43um) [733/30400]
# Completed (w_t=5.28um, l_t=876.19um) [734/30400]
# Completed (w_t=5.28um, l_t=880.95um) [735/30400]
# Completed (w_t=5.28um, l_t=885.71um) [736/30400]
# Completed (w_t=5.28um, l_t=890.48um) [737/30400]
# Completed (w_t=5.28um, l_t=895.24um) [738/30400]
# Completed (w_t=5.28um, l_t=900.00um) [739/30400]
# Completed (w_t=5.28um, l_t=904.76um) [740/30400]
# Completed (w_t=5.28um, l_t=909.52um) [741/30400]
# Completed (w_t=5.28um, l_t=914.29um) [742/30400]
# Completed (w_t=5.28um, l_t=919.05um) [743/30400]
# Completed (w_t=5.28um, l_t=923.81um) [744/30400]
# Completed (w_t=5.28um, l_t=928.57um) [745/30400]
# Completed (w_t=5.28um, l_t=933.33um) [746/30400]
# Completed (w_t=5.28um, l_t=938.10um) [747/30400]
# Completed (w_t=5.28um, l_t=942.86um) [748/30400]
# Completed (w_t=5.28um, l_t=947.62um) [749/30400]
# Completed (w_t=5.28um, l_t=952.38um) [750/30400]
# Completed (w_t=5.28um, l_t=957.14um) [751/30400]
# Completed (w_t=5.28um, l_t=961.90um) [752/30400]
# Completed (w_t=5.28um, l_t=966.67um) [753/30400]
# Completed (w_t=5.28um, l_t=971.43um) [754/30400]
# Completed (w_t=5.28um, l_t=976.19um) [755/30400]
# Completed (w_t=5.28um, l_t=980.95um) [756/30400]
# Completed (w_t=5.28um, l_t=985.71um) [757/30400]
# Completed (w_t=5.28um, l_t=990.48um) [758/30400]
# Completed (w_t=5.28um, l_t=995.24um) [759/30400]
# Completed (w_t=5.28um, l_t=1000.00um) [760/30400]
# Completed (w_t=5.38um, l_t=100.00um) [761/30400]
# Completed (w_t=5.38um, l_t=104.76um) [762/30400]
# Completed (w_t=5.38um, l_t=109.52um) [763/30400]
# Completed (w_t=5.38um, l_t=114.29um) [764/30400]
# Completed (w_t=5.38um, l_t=119.05um) [765/30400]
# Completed (w_t=5.38um, l_t=123.81um) [766/30400]
# Completed (w_t=5.38um, l_t=128.57um) [767/30400]
# Completed (w_t=5.38um, l_t=133.33um) [768/30400]
# Completed (w_t=5.38um, l_t=138.10um) [769/30400]
# Completed (w_t=5.38um, l_t=142.86um) [770/30400]
# Completed (w_t=5.38um, l_t=147.62um) [771/30400]
# Completed (w_t=5.38um, l_t=152.38um) [772/30400]
# Completed (w_t=5.38um, l_t=157.14um) [773/30400]
# Completed (w_t=5.38um, l_t=161.90um) [774/30400]
# Completed (w_t=5.38um, l_t=166.67um) [775/30400]
# Completed (w_t=5.38um, l_t=171.43um) [776/30400]
# Completed (w_t=5.38um, l_t=176.19um) [777/30400]
# Completed (w_t=5.38um, l_t=180.95um) [778/30400]
# Completed (w_t=5.38um, l_t=185.71um) [779/30400]
# Completed (w_t=5.38um, l_t=190.48um) [780/30400]
# Completed (w_t=5.38um, l_t=195.24um) [781/30400]
# Completed (w_t=5.38um, l_t=200.00um) [782/30400]
# Completed (w_t=5.38um, l_t=204.76um) [783/30400]
# Completed (w_t=5.38um, l_t=209.52um) [784/30400]
# Completed (w_t=5.38um, l_t=214.29um) [785/30400]
# Completed (w_t=5.38um, l_t=219.05um) [786/30400]
# Completed (w_t=5.38um, l_t=223.81um) [787/30400]
# Completed (w_t=5.38um, l_t=228.57um) [788/30400]
# Completed (w_t=5.38um, l_t=233.33um) [789/30400]
# Completed (w_t=5.38um, l_t=238.10um) [790/30400]
# Completed (w_t=5.38um, l_t=242.86um) [791/30400]
# Completed (w_t=5.38um, l_t=247.62um) [792/30400]
# Completed (w_t=5.38um, l_t=252.38um) [793/30400]
# Completed (w_t=5.38um, l_t=257.14um) [794/30400]
# Completed (w_t=5.38um, l_t=261.90um) [795/30400]
# Completed (w_t=5.38um, l_t=266.67um) [796/30400]
# Completed (w_t=5.38um, l_t=271.43um) [797/30400]
# Completed (w_t=5.38um, l_t=276.19um) [798/30400]
# Completed (w_t=5.38um, l_t=280.95um) [799/30400]
# Completed (w_t=5.38um, l_t=285.71um) [800/30400]
# Completed (w_t=5.38um, l_t=290.48um) [801/30400]
# Completed (w_t=5.38um, l_t=295.24um) [802/30400]
# Completed (w_t=5.38um, l_t=300.00um) [803/30400]
# Completed (w_t=5.38um, l_t=304.76um) [804/30400]
# Completed (w_t=5.38um, l_t=309.52um) [805/30400]
# Completed (w_t=5.38um, l_t=314.29um) [806/30400]
# Completed (w_t=5.38um, l_t=319.05um) [807/30400]
# Completed (w_t=5.38um, l_t=323.81um) [808/30400]
# Completed (w_t=5.38um, l_t=328.57um) [809/30400]
# Completed (w_t=5.38um, l_t=333.33um) [810/30400]
# Completed (w_t=5.38um, l_t=338.10um) [811/30400]
# Completed (w_t=5.38um, l_t=342.86um) [812/30400]
# Completed (w_t=5.38um, l_t=347.62um) [813/30400]
# Completed (w_t=5.38um, l_t=352.38um) [814/30400]
# Completed (w_t=5.38um, l_t=357.14um) [815/30400]
# Completed (w_t=5.38um, l_t=361.90um) [816/30400]
# Completed (w_t=5.38um, l_t=366.67um) [817/30400]
# Completed (w_t=5.38um, l_t=371.43um) [818/30400]
# Completed (w_t=5.38um, l_t=376.19um) [819/30400]
# Completed (w_t=5.38um, l_t=380.95um) [820/30400]
# Completed (w_t=5.38um, l_t=385.71um) [821/30400]
# Completed (w_t=5.38um, l_t=390.48um) [822/30400]
# Completed (w_t=5.38um, l_t=395.24um) [823/30400]
# Completed (w_t=5.38um, l_t=400.00um) [824/30400]
# Completed (w_t=5.38um, l_t=404.76um) [825/30400]
# Completed (w_t=5.38um, l_t=409.52um) [826/30400]
# Completed (w_t=5.38um, l_t=414.29um) [827/30400]
# Completed (w_t=5.38um, l_t=419.05um) [828/30400]
# Completed (w_t=5.38um, l_t=423.81um) [829/30400]
# Completed (w_t=5.38um, l_t=428.57um) [830/30400]
# Completed (w_t=5.38um, l_t=433.33um) [831/30400]
# Completed (w_t=5.38um, l_t=438.10um) [832/30400]
# Completed (w_t=5.38um, l_t=442.86um) [833/30400]
# Completed (w_t=5.38um, l_t=447.62um) [834/30400]
# Completed (w_t=5.38um, l_t=452.38um) [835/30400]
# Completed (w_t=5.38um, l_t=457.14um) [836/30400]
# Completed (w_t=5.38um, l_t=461.90um) [837/30400]
# Completed (w_t=5.38um, l_t=466.67um) [838/30400]
# Completed (w_t=5.38um, l_t=471.43um) [839/30400]
# Completed (w_t=5.38um, l_t=476.19um) [840/30400]
# Completed (w_t=5.38um, l_t=480.95um) [841/30400]
# Completed (w_t=5.38um, l_t=485.71um) [842/30400]
# Completed (w_t=5.38um, l_t=490.48um) [843/30400]
# Completed (w_t=5.38um, l_t=495.24um) [844/30400]
# Completed (w_t=5.38um, l_t=500.00um) [845/30400]
# Completed (w_t=5.38um, l_t=504.76um) [846/30400]
# Completed (w_t=5.38um, l_t=509.52um) [847/30400]
# Completed (w_t=5.38um, l_t=514.29um) [848/30400]
# Completed (w_t=5.38um, l_t=519.05um) [849/30400]
# Completed (w_t=5.38um, l_t=523.81um) [850/30400]
# Completed (w_t=5.38um, l_t=528.57um) [851/30400]
# Completed (w_t=5.38um, l_t=533.33um) [852/30400]
# Completed (w_t=5.38um, l_t=538.10um) [853/30400]
# Completed (w_t=5.38um, l_t=542.86um) [854/30400]
# Completed (w_t=5.38um, l_t=547.62um) [855/30400]
# Completed (w_t=5.38um, l_t=552.38um) [856/30400]
# Completed (w_t=5.38um, l_t=557.14um) [857/30400]
# Completed (w_t=5.38um, l_t=561.90um) [858/30400]
# Completed (w_t=5.38um, l_t=566.67um) [859/30400]
# Completed (w_t=5.38um, l_t=571.43um) [860/30400]
# Completed (w_t=5.38um, l_t=576.19um) [861/30400]
# Completed (w_t=5.38um, l_t=580.95um) [862/30400]
# Completed (w_t=5.38um, l_t=585.71um) [863/30400]
# Completed (w_t=5.38um, l_t=590.48um) [864/30400]
# Completed (w_t=5.38um, l_t=595.24um) [865/30400]
# Completed (w_t=5.38um, l_t=600.00um) [866/30400]
# Completed (w_t=5.38um, l_t=604.76um) [867/30400]
# Completed (w_t=5.38um, l_t=609.52um) [868/30400]
# Completed (w_t=5.38um, l_t=614.29um) [869/30400]
# Completed (w_t=5.38um, l_t=619.05um) [870/30400]
# Completed (w_t=5.38um, l_t=623.81um) [871/30400]
# Completed (w_t=5.38um, l_t=628.57um) [872/30400]
# Completed (w_t=5.38um, l_t=633.33um) [873/30400]
# Completed (w_t=5.38um, l_t=638.10um) [874/30400]
# Completed (w_t=5.38um, l_t=642.86um) [875/30400]
# Completed (w_t=5.38um, l_t=647.62um) [876/30400]
# Completed (w_t=5.38um, l_t=652.38um) [877/30400]
# Completed (w_t=5.38um, l_t=657.14um) [878/30400]
# Completed (w_t=5.38um, l_t=661.90um) [879/30400]
# Completed (w_t=5.38um, l_t=666.67um) [880/30400]
# Completed (w_t=5.38um, l_t=671.43um) [881/30400]
# Completed (w_t=5.38um, l_t=676.19um) [882/30400]
# Completed (w_t=5.38um, l_t=680.95um) [883/30400]
# Completed (w_t=5.38um, l_t=685.71um) [884/30400]
# Completed (w_t=5.38um, l_t=690.48um) [885/30400]
# Completed (w_t=5.38um, l_t=695.24um) [886/30400]
# Completed (w_t=5.38um, l_t=700.00um) [887/30400]
# Completed (w_t=5.38um, l_t=704.76um) [888/30400]
# Completed (w_t=5.38um, l_t=709.52um) [889/30400]
# Completed (w_t=5.38um, l_t=714.29um) [890/30400]
# Completed (w_t=5.38um, l_t=719.05um) [891/30400]
# Completed (w_t=5.38um, l_t=723.81um) [892/30400]
# Completed (w_t=5.38um, l_t=728.57um) [893/30400]
# Completed (w_t=5.38um, l_t=733.33um) [894/30400]
# Completed (w_t=5.38um, l_t=738.10um) [895/30400]
# Completed (w_t=5.38um, l_t=742.86um) [896/30400]
# Completed (w_t=5.38um, l_t=747.62um) [897/30400]
# Completed (w_t=5.38um, l_t=752.38um) [898/30400]
# Completed (w_t=5.38um, l_t=757.14um) [899/30400]
# Completed (w_t=5.38um, l_t=761.90um) [900/30400]
# Completed (w_t=5.38um, l_t=766.67um) [901/30400]
# Completed (w_t=5.38um, l_t=771.43um) [902/30400]
# Completed (w_t=5.38um, l_t=776.19um) [903/30400]
# Completed (w_t=5.38um, l_t=780.95um) [904/30400]
# Completed (w_t=5.38um, l_t=785.71um) [905/30400]
# Completed (w_t=5.38um, l_t=790.48um) [906/30400]
# Completed (w_t=5.38um, l_t=795.24um) [907/30400]
# Completed (w_t=5.38um, l_t=800.00um) [908/30400]
# Completed (w_t=5.38um, l_t=804.76um) [909/30400]
# Completed (w_t=5.38um, l_t=809.52um) [910/30400]
# Completed (w_t=5.38um, l_t=814.29um) [911/30400]
# Completed (w_t=5.38um, l_t=819.05um) [912/30400]
# Completed (w_t=5.38um, l_t=823.81um) [913/30400]
# Completed (w_t=5.38um, l_t=828.57um) [914/30400]
# Completed (w_t=5.38um, l_t=833.33um) [915/30400]
# Completed (w_t=5.38um, l_t=838.10um) [916/30400]
# Completed (w_t=5.38um, l_t=842.86um) [917/30400]
# Completed (w_t=5.38um, l_t=847.62um) [918/30400]
# Completed (w_t=5.38um, l_t=852.38um) [919/30400]
# Completed (w_t=5.38um, l_t=857.14um) [920/30400]
# Completed (w_t=5.38um, l_t=861.90um) [921/30400]
# Completed (w_t=5.38um, l_t=866.67um) [922/30400]
# Completed (w_t=5.38um, l_t=871.43um) [923/30400]
# Completed (w_t=5.38um, l_t=876.19um) [924/30400]
# Completed (w_t=5.38um, l_t=880.95um) [925/30400]
# Completed (w_t=5.38um, l_t=885.71um) [926/30400]
# Completed (w_t=5.38um, l_t=890.48um) [927/30400]
# Completed (w_t=5.38um, l_t=895.24um) [928/30400]
# Completed (w_t=5.38um, l_t=900.00um) [929/30400]
# Completed (w_t=5.38um, l_t=904.76um) [930/30400]
# Completed (w_t=5.38um, l_t=909.52um) [931/30400]
# Completed (w_t=5.38um, l_t=914.29um) [932/30400]
# Completed (w_t=5.38um, l_t=919.05um) [933/30400]
# Completed (w_t=5.38um, l_t=923.81um) [934/30400]
# Completed (w_t=5.38um, l_t=928.57um) [935/30400]
# Completed (w_t=5.38um, l_t=933.33um) [936/30400]
# Completed (w_t=5.38um, l_t=938.10um) [937/30400]
# Completed (w_t=5.38um, l_t=942.86um) [938/30400]
# Completed (w_t=5.38um, l_t=947.62um) [939/30400]
# Completed (w_t=5.38um, l_t=952.38um) [940/30400]
# Completed (w_t=5.38um, l_t=957.14um) [941/30400]
# Completed (w_t=5.38um, l_t=961.90um) [942/30400]
# Completed (w_t=5.38um, l_t=966.67um) [943/30400]
# Completed (w_t=5.38um, l_t=971.43um) [944/30400]
# Completed (w_t=5.38um, l_t=976.19um) [945/30400]
# Completed (w_t=5.38um, l_t=980.95um) [946/30400]
# Completed (w_t=5.38um, l_t=985.71um) [947/30400]
# Completed (w_t=5.38um, l_t=990.48um) [948/30400]
# Completed (w_t=5.38um, l_t=995.24um) [949/30400]
# Completed (w_t=5.38um, l_t=1000.00um) [950/30400]
# Completed (w_t=5.47um, l_t=100.00um) [951/30400]
# Completed (w_t=5.47um, l_t=104.76um) [952/30400]
# Completed (w_t=5.47um, l_t=109.52um) [953/30400]
# Completed (w_t=5.47um, l_t=114.29um) [954/30400]
# Completed (w_t=5.47um, l_t=119.05um) [955/30400]
# Completed (w_t=5.47um, l_t=123.81um) [956/30400]
# Completed (w_t=5.47um, l_t=128.57um) [957/30400]
# Completed (w_t=5.47um, l_t=133.33um) [958/30400]
# Completed (w_t=5.47um, l_t=138.10um) [959/30400]
# Completed (w_t=5.47um, l_t=142.86um) [960/30400]
# Completed (w_t=5.47um, l_t=147.62um) [961/30400]
# Completed (w_t=5.47um, l_t=152.38um) [962/30400]
# Completed (w_t=5.47um, l_t=157.14um) [963/30400]
# Completed (w_t=5.47um, l_t=161.90um) [964/30400]
# Completed (w_t=5.47um, l_t=166.67um) [965/30400]
# Completed (w_t=5.47um, l_t=171.43um) [966/30400]
# Completed (w_t=5.47um, l_t=176.19um) [967/30400]
# Completed (w_t=5.47um, l_t=180.95um) [968/30400]
# Completed (w_t=5.47um, l_t=185.71um) [969/30400]
# Completed (w_t=5.47um, l_t=190.48um) [970/30400]
# Completed (w_t=5.47um, l_t=195.24um) [971/30400]
# Completed (w_t=5.47um, l_t=200.00um) [972/30400]
# Completed (w_t=5.47um, l_t=204.76um) [973/30400]
# Completed (w_t=5.47um, l_t=209.52um) [974/30400]
# Completed (w_t=5.47um, l_t=214.29um) [975/30400]
# Completed (w_t=5.47um, l_t=219.05um) [976/30400]
# Completed (w_t=5.47um, l_t=223.81um) [977/30400]
# Completed (w_t=5.47um, l_t=228.57um) [978/30400]
# Completed (w_t=5.47um, l_t=233.33um) [979/30400]
# Completed (w_t=5.47um, l_t=238.10um) [980/30400]
# Completed (w_t=5.47um, l_t=242.86um) [981/30400]
# ...
# Completed (w_t=19.91um, l_t=480.95um) [30101/30400]
# Completed (w_t=19.91um, l_t=485.71um) [30102/30400]
# Completed (w_t=19.91um, l_t=490.48um) [30103/30400]
# Completed (w_t=19.91um, l_t=495.24um) [30104/30400]
# Completed (w_t=19.91um, l_t=500.00um) [30105/30400]
# Completed (w_t=19.91um, l_t=504.76um) [30106/30400]
# Completed (w_t=19.91um, l_t=509.52um) [30107/30400]
# Completed (w_t=19.91um, l_t=514.29um) [30108/30400]
# Completed (w_t=19.91um, l_t=519.05um) [30109/30400]
# Completed (w_t=19.91um, l_t=523.81um) [30110/30400]
# Completed (w_t=19.91um, l_t=528.57um) [30111/30400]
# Completed (w_t=19.91um, l_t=533.33um) [30112/30400]
# Completed (w_t=19.91um, l_t=538.10um) [30113/30400]
# Completed (w_t=19.91um, l_t=542.86um) [30114/30400]
# Completed (w_t=19.91um, l_t=547.62um) [30115/30400]
# Completed (w_t=19.91um, l_t=552.38um) [30116/30400]
# Completed (w_t=19.91um, l_t=557.14um) [30117/30400]
# Completed (w_t=19.91um, l_t=561.90um) [30118/30400]
# Completed (w_t=19.91um, l_t=566.67um) [30119/30400]
# Completed (w_t=19.91um, l_t=571.43um) [30120/30400]
# Completed (w_t=19.91um, l_t=576.19um) [30121/30400]
# Completed (w_t=19.91um, l_t=580.95um) [30122/30400]
# Completed (w_t=19.91um, l_t=585.71um) [30123/30400]
# Completed (w_t=19.91um, l_t=590.48um) [30124/30400]
# Completed (w_t=19.91um, l_t=595.24um) [30125/30400]
# Completed (w_t=19.91um, l_t=600.00um) [30126/30400]
# Completed (w_t=19.91um, l_t=604.76um) [30127/30400]
# Completed (w_t=19.91um, l_t=609.52um) [30128/30400]
# Completed (w_t=19.91um, l_t=614.29um) [30129/30400]
# Completed (w_t=19.91um, l_t=619.05um) [30130/30400]
# Completed (w_t=19.91um, l_t=623.81um) [30131/30400]
# Completed (w_t=19.91um, l_t=628.57um) [30132/30400]
# Completed (w_t=19.91um, l_t=633.33um) [30133/30400]
# Completed (w_t=19.91um, l_t=638.10um) [30134/30400]
# Completed (w_t=19.91um, l_t=642.86um) [30135/30400]
# Completed (w_t=19.91um, l_t=647.62um) [30136/30400]
# Completed (w_t=19.91um, l_t=652.38um) [30137/30400]
# Completed (w_t=19.91um, l_t=657.14um) [30138/30400]
# Completed (w_t=19.91um, l_t=661.90um) [30139/30400]
# Completed (w_t=19.91um, l_t=666.67um) [30140/30400]
# Completed (w_t=19.91um, l_t=671.43um) [30141/30400]
# Completed (w_t=19.91um, l_t=676.19um) [30142/30400]
# Completed (w_t=19.91um, l_t=680.95um) [30143/30400]
# Completed (w_t=19.91um, l_t=685.71um) [30144/30400]
# Completed (w_t=19.91um, l_t=690.48um) [30145/30400]
# Completed (w_t=19.91um, l_t=695.24um) [30146/30400]
# Completed (w_t=19.91um, l_t=700.00um) [30147/30400]
# Completed (w_t=19.91um, l_t=704.76um) [30148/30400]
# Completed (w_t=19.91um, l_t=709.52um) [30149/30400]
# Completed (w_t=19.91um, l_t=714.29um) [30150/30400]
# Completed (w_t=19.91um, l_t=719.05um) [30151/30400]
# Completed (w_t=19.91um, l_t=723.81um) [30152/30400]
# Completed (w_t=19.91um, l_t=728.57um) [30153/30400]
# Completed (w_t=19.91um, l_t=733.33um) [30154/30400]
# Completed (w_t=19.91um, l_t=738.10um) [30155/30400]
# Completed (w_t=19.91um, l_t=742.86um) [30156/30400]
# Completed (w_t=19.91um, l_t=747.62um) [30157/30400]
# Completed (w_t=19.91um, l_t=752.38um) [30158/30400]
# Completed (w_t=19.91um, l_t=757.14um) [30159/30400]
# Completed (w_t=19.91um, l_t=761.90um) [30160/30400]
# Completed (w_t=19.91um, l_t=766.67um) [30161/30400]
# Completed (w_t=19.91um, l_t=771.43um) [30162/30400]
# Completed (w_t=19.91um, l_t=776.19um) [30163/30400]
# Completed (w_t=19.91um, l_t=780.95um) [30164/30400]
# Completed (w_t=19.91um, l_t=785.71um) [30165/30400]
# Completed (w_t=19.91um, l_t=790.48um) [30166/30400]
# Completed (w_t=19.91um, l_t=795.24um) [30167/30400]
# Completed (w_t=19.91um, l_t=800.00um) [30168/30400]
# Completed (w_t=19.91um, l_t=804.76um) [30169/30400]
# Completed (w_t=19.91um, l_t=809.52um) [30170/30400]
# Completed (w_t=19.91um, l_t=814.29um) [30171/30400]
# Completed (w_t=19.91um, l_t=819.05um) [30172/30400]
# Completed (w_t=19.91um, l_t=823.81um) [30173/30400]
# Completed (w_t=19.91um, l_t=828.57um) [30174/30400]
# Completed (w_t=19.91um, l_t=833.33um) [30175/30400]
# Completed (w_t=19.91um, l_t=838.10um) [30176/30400]
# Completed (w_t=19.91um, l_t=842.86um) [30177/30400]
# Completed (w_t=19.91um, l_t=847.62um) [30178/30400]
# Completed (w_t=19.91um, l_t=852.38um) [30179/30400]
# Completed (w_t=19.91um, l_t=857.14um) [30180/30400]
# Completed (w_t=19.91um, l_t=861.90um) [30181/30400]
# Completed (w_t=19.91um, l_t=866.67um) [30182/30400]
# Completed (w_t=19.91um, l_t=871.43um) [30183/30400]
# Completed (w_t=19.91um, l_t=876.19um) [30184/30400]
# Completed (w_t=19.91um, l_t=880.95um) [30185/30400]
# Completed (w_t=19.91um, l_t=885.71um) [30186/30400]
# Completed (w_t=19.91um, l_t=890.48um) [30187/30400]
# Completed (w_t=19.91um, l_t=895.24um) [30188/30400]
# Completed (w_t=19.91um, l_t=900.00um) [30189/30400]
# Completed (w_t=19.91um, l_t=904.76um) [30190/30400]
# Completed (w_t=19.91um, l_t=909.52um) [30191/30400]
# Completed (w_t=19.91um, l_t=914.29um) [30192/30400]
# Completed (w_t=19.91um, l_t=919.05um) [30193/30400]
# Completed (w_t=19.91um, l_t=923.81um) [30194/30400]
# Completed (w_t=19.91um, l_t=928.57um) [30195/30400]
# Completed (w_t=19.91um, l_t=933.33um) [30196/30400]
# Completed (w_t=19.91um, l_t=938.10um) [30197/30400]
# Completed (w_t=19.91um, l_t=942.86um) [30198/30400]
# Completed (w_t=19.91um, l_t=947.62um) [30199/30400]
# Completed (w_t=19.91um, l_t=952.38um) [30200/30400]
# Completed (w_t=19.91um, l_t=957.14um) [30201/30400]
# Completed (w_t=19.91um, l_t=961.90um) [30202/30400]
# Completed (w_t=19.91um, l_t=966.67um) [30203/30400]
# Completed (w_t=19.91um, l_t=971.43um) [30204/30400]
# Completed (w_t=19.91um, l_t=976.19um) [30205/30400]
# Completed (w_t=19.91um, l_t=980.95um) [30206/30400]
# Completed (w_t=19.91um, l_t=985.71um) [30207/30400]
# Completed (w_t=19.91um, l_t=990.48um) [30208/30400]
# Completed (w_t=19.91um, l_t=995.24um) [30209/30400]
# Completed (w_t=19.91um, l_t=1000.00um) [30210/30400]
# Completed (w_t=20.00um, l_t=100.00um) [30211/30400]
# Completed (w_t=20.00um, l_t=104.76um) [30212/30400]
# Completed (w_t=20.00um, l_t=109.52um) [30213/30400]
# Completed (w_t=20.00um, l_t=114.29um) [30214/30400]
# Completed (w_t=20.00um, l_t=119.05um) [30215/30400]
# Completed (w_t=20.00um, l_t=123.81um) [30216/30400]
# Completed (w_t=20.00um, l_t=128.57um) [30217/30400]
# Completed (w_t=20.00um, l_t=133.33um) [30218/30400]
# Completed (w_t=20.00um, l_t=138.10um) [30219/30400]
# Completed (w_t=20.00um, l_t=142.86um) [30220/30400]
# Completed (w_t=20.00um, l_t=147.62um) [30221/30400]
# Completed (w_t=20.00um, l_t=152.38um) [30222/30400]
# Completed (w_t=20.00um, l_t=157.14um) [30223/30400]
# Completed (w_t=20.00um, l_t=161.90um) [30224/30400]
# Completed (w_t=20.00um, l_t=166.67um) [30225/30400]
# Completed (w_t=20.00um, l_t=171.43um) [30226/30400]
# Completed (w_t=20.00um, l_t=176.19um) [30227/30400]
# Completed (w_t=20.00um, l_t=180.95um) [30228/30400]
# Completed (w_t=20.00um, l_t=185.71um) [30229/30400]
# Completed (w_t=20.00um, l_t=190.48um) [30230/30400]
# Completed (w_t=20.00um, l_t=195.24um) [30231/30400]
# Completed (w_t=20.00um, l_t=200.00um) [30232/30400]
# Completed (w_t=20.00um, l_t=204.76um) [30233/30400]
# Completed (w_t=20.00um, l_t=209.52um) [30234/30400]
# Completed (w_t=20.00um, l_t=214.29um) [30235/30400]
# Completed (w_t=20.00um, l_t=219.05um) [30236/30400]
# Completed (w_t=20.00um, l_t=223.81um) [30237/30400]
# Completed (w_t=20.00um, l_t=228.57um) [30238/30400]
# Completed (w_t=20.00um, l_t=233.33um) [30239/30400]
# Completed (w_t=20.00um, l_t=238.10um) [30240/30400]
# Completed (w_t=20.00um, l_t=242.86um) [30241/30400]
# Completed (w_t=20.00um, l_t=247.62um) [30242/30400]
# Completed (w_t=20.00um, l_t=252.38um) [30243/30400]
# Completed (w_t=20.00um, l_t=257.14um) [30244/30400]
# Completed (w_t=20.00um, l_t=261.90um) [30245/30400]
# Completed (w_t=20.00um, l_t=266.67um) [30246/30400]
# Completed (w_t=20.00um, l_t=271.43um) [30247/30400]
# Completed (w_t=20.00um, l_t=276.19um) [30248/30400]
# Completed (w_t=20.00um, l_t=280.95um) [30249/30400]
# Completed (w_t=20.00um, l_t=285.71um) [30250/30400]
# Completed (w_t=20.00um, l_t=290.48um) [30251/30400]
# Completed (w_t=20.00um, l_t=295.24um) [30252/30400]
# Completed (w_t=20.00um, l_t=300.00um) [30253/30400]
# Completed (w_t=20.00um, l_t=304.76um) [30254/30400]
# Completed (w_t=20.00um, l_t=309.52um) [30255/30400]
# Completed (w_t=20.00um, l_t=314.29um) [30256/30400]
# Completed (w_t=20.00um, l_t=319.05um) [30257/30400]
# Completed (w_t=20.00um, l_t=323.81um) [30258/30400]
# Completed (w_t=20.00um, l_t=328.57um) [30259/30400]
# Completed (w_t=20.00um, l_t=333.33um) [30260/30400]
# Completed (w_t=20.00um, l_t=338.10um) [30261/30400]
# Completed (w_t=20.00um, l_t=342.86um) [30262/30400]
# Completed (w_t=20.00um, l_t=347.62um) [30263/30400]
# Completed (w_t=20.00um, l_t=352.38um) [30264/30400]
# Completed (w_t=20.00um, l_t=357.14um) [30265/30400]
# Completed (w_t=20.00um, l_t=361.90um) [30266/30400]
# Completed (w_t=20.00um, l_t=366.67um) [30267/30400]
# Completed (w_t=20.00um, l_t=371.43um) [30268/30400]
# Completed (w_t=20.00um, l_t=376.19um) [30269/30400]
# Completed (w_t=20.00um, l_t=380.95um) [30270/30400]
# Completed (w_t=20.00um, l_t=385.71um) [30271/30400]
# Completed (w_t=20.00um, l_t=390.48um) [30272/30400]
# Completed (w_t=20.00um, l_t=395.24um) [30273/30400]
# Completed (w_t=20.00um, l_t=400.00um) [30274/30400]
# Completed (w_t=20.00um, l_t=404.76um) [30275/30400]
# Completed (w_t=20.00um, l_t=409.52um) [30276/30400]
# Completed (w_t=20.00um, l_t=414.29um) [30277/30400]
# Completed (w_t=20.00um, l_t=419.05um) [30278/30400]
# Completed (w_t=20.00um, l_t=423.81um) [30279/30400]
# Completed (w_t=20.00um, l_t=428.57um) [30280/30400]
# Completed (w_t=20.00um, l_t=433.33um) [30281/30400]
# Completed (w_t=20.00um, l_t=438.10um) [30282/30400]
# Completed (w_t=20.00um, l_t=442.86um) [30283/30400]
# Completed (w_t=20.00um, l_t=447.62um) [30284/30400]
# Completed (w_t=20.00um, l_t=452.38um) [30285/30400]
# Completed (w_t=20.00um, l_t=457.14um) [30286/30400]
# Completed (w_t=20.00um, l_t=461.90um) [30287/30400]
# Completed (w_t=20.00um, l_t=466.67um) [30288/30400]
# Completed (w_t=20.00um, l_t=471.43um) [30289/30400]
# Completed (w_t=20.00um, l_t=476.19um) [30290/30400]
# Completed (w_t=20.00um, l_t=480.95um) [30291/30400]
# Completed (w_t=20.00um, l_t=485.71um) [30292/30400]
# Completed (w_t=20.00um, l_t=490.48um) [30293/30400]
# Completed (w_t=20.00um, l_t=495.24um) [30294/30400]
# Completed (w_t=20.00um, l_t=500.00um) [30295/30400]
# Completed (w_t=20.00um, l_t=504.76um) [30296/30400]
# Completed (w_t=20.00um, l_t=509.52um) [30297/30400]
# Completed (w_t=20.00um, l_t=514.29um) [30298/30400]
# Completed (w_t=20.00um, l_t=519.05um) [30299/30400]
# Completed (w_t=20.00um, l_t=523.81um) [30300/30400]
# Completed (w_t=20.00um, l_t=528.57um) [30301/30400]
# Completed (w_t=20.00um, l_t=533.33um) [30302/30400]
# Completed (w_t=20.00um, l_t=538.10um) [30303/30400]
# Completed (w_t=20.00um, l_t=542.86um) [30304/30400]
# Completed (w_t=20.00um, l_t=547.62um) [30305/30400]
# Completed (w_t=20.00um, l_t=552.38um) [30306/30400]
# Completed (w_t=20.00um, l_t=557.14um) [30307/30400]
# Completed (w_t=20.00um, l_t=561.90um) [30308/30400]
# Completed (w_t=20.00um, l_t=566.67um) [30309/30400]
# Completed (w_t=20.00um, l_t=571.43um) [30310/30400]
# Completed (w_t=20.00um, l_t=576.19um) [30311/30400]
# Completed (w_t=20.00um, l_t=580.95um) [30312/30400]
# Completed (w_t=20.00um, l_t=585.71um) [30313/30400]
# Completed (w_t=20.00um, l_t=590.48um) [30314/30400]
# Completed (w_t=20.00um, l_t=595.24um) [30315/30400]
# Completed (w_t=20.00um, l_t=600.00um) [30316/30400]
# Completed (w_t=20.00um, l_t=604.76um) [30317/30400]
# Completed (w_t=20.00um, l_t=609.52um) [30318/30400]
# Completed (w_t=20.00um, l_t=614.29um) [30319/30400]
# Completed (w_t=20.00um, l_t=619.05um) [30320/30400]
# Completed (w_t=20.00um, l_t=623.81um) [30321/30400]
# Completed (w_t=20.00um, l_t=628.57um) [30322/30400]
# Completed (w_t=20.00um, l_t=633.33um) [30323/30400]
# Completed (w_t=20.00um, l_t=638.10um) [30324/30400]
# Completed (w_t=20.00um, l_t=642.86um) [30325/30400]
# Completed (w_t=20.00um, l_t=647.62um) [30326/30400]
# Completed (w_t=20.00um, l_t=652.38um) [30327/30400]
# Completed (w_t=20.00um, l_t=657.14um) [30328/30400]
# Completed (w_t=20.00um, l_t=661.90um) [30329/30400]
# Completed (w_t=20.00um, l_t=666.67um) [30330/30400]
# Completed (w_t=20.00um, l_t=671.43um) [30331/30400]
# Completed (w_t=20.00um, l_t=676.19um) [30332/30400]
# Completed (w_t=20.00um, l_t=680.95um) [30333/30400]
# Completed (w_t=20.00um, l_t=685.71um) [30334/30400]
# Completed (w_t=20.00um, l_t=690.48um) [30335/30400]
# Completed (w_t=20.00um, l_t=695.24um) [30336/30400]
# Completed (w_t=20.00um, l_t=700.00um) [30337/30400]
# Completed (w_t=20.00um, l_t=704.76um) [30338/30400]
# Completed (w_t=20.00um, l_t=709.52um) [30339/30400]
# Completed (w_t=20.00um, l_t=714.29um) [30340/30400]
# Completed (w_t=20.00um, l_t=719.05um) [30341/30400]
# Completed (w_t=20.00um, l_t=723.81um) [30342/30400]
# Completed (w_t=20.00um, l_t=728.57um) [30343/30400]
# Completed (w_t=20.00um, l_t=733.33um) [30344/30400]
# Completed (w_t=20.00um, l_t=738.10um) [30345/30400]
# Completed (w_t=20.00um, l_t=742.86um) [30346/30400]
# Completed (w_t=20.00um, l_t=747.62um) [30347/30400]
# Completed (w_t=20.00um, l_t=752.38um) [30348/30400]
# Completed (w_t=20.00um, l_t=757.14um) [30349/30400]
# Completed (w_t=20.00um, l_t=761.90um) [30350/30400]
# Completed (w_t=20.00um, l_t=766.67um) [30351/30400]
# Completed (w_t=20.00um, l_t=771.43um) [30352/30400]
# Completed (w_t=20.00um, l_t=776.19um) [30353/30400]
# Completed (w_t=20.00um, l_t=780.95um) [30354/30400]
# Completed (w_t=20.00um, l_t=785.71um) [30355/30400]
# Completed (w_t=20.00um, l_t=790.48um) [30356/30400]
# Completed (w_t=20.00um, l_t=795.24um) [30357/30400]
# Completed (w_t=20.00um, l_t=800.00um) [30358/30400]
# Completed (w_t=20.00um, l_t=804.76um) [30359/30400]
# Completed (w_t=20.00um, l_t=809.52um) [30360/30400]
# Completed (w_t=20.00um, l_t=814.29um) [30361/30400]
# Completed (w_t=20.00um, l_t=819.05um) [30362/30400]
# Completed (w_t=20.00um, l_t=823.81um) [30363/30400]
# Completed (w_t=20.00um, l_t=828.57um) [30364/30400]
# Completed (w_t=20.00um, l_t=833.33um) [30365/30400]
# Completed (w_t=20.00um, l_t=838.10um) [30366/30400]
# Completed (w_t=20.00um, l_t=842.86um) [30367/30400]
# Completed (w_t=20.00um, l_t=847.62um) [30368/30400]
# Completed (w_t=20.00um, l_t=852.38um) [30369/30400]
# Completed (w_t=20.00um, l_t=857.14um) [30370/30400]
# Completed (w_t=20.00um, l_t=861.90um) [30371/30400]
# Completed (w_t=20.00um, l_t=866.67um) [30372/30400]
# Completed (w_t=20.00um, l_t=871.43um) [30373/30400]
# Completed (w_t=20.00um, l_t=876.19um) [30374/30400]
# Completed (w_t=20.00um, l_t=880.95um) [30375/30400]
# Completed (w_t=20.00um, l_t=885.71um) [30376/30400]
# Completed (w_t=20.00um, l_t=890.48um) [30377/30400]
# Completed (w_t=20.00um, l_t=895.24um) [30378/30400]
# Completed (w_t=20.00um, l_t=900.00um) [30379/30400]
# Completed (w_t=20.00um, l_t=904.76um) [30380/30400]
# Completed (w_t=20.00um, l_t=909.52um) [30381/30400]
# Completed (w_t=20.00um, l_t=914.29um) [30382/30400]
# Completed (w_t=20.00um, l_t=919.05um) [30383/30400]
# Completed (w_t=20.00um, l_t=923.81um) [30384/30400]
# Completed (w_t=20.00um, l_t=928.57um) [30385/30400]
# Completed (w_t=20.00um, l_t=933.33um) [30386/30400]
# Completed (w_t=20.00um, l_t=938.10um) [30387/30400]
# Completed (w_t=20.00um, l_t=942.86um) [30388/30400]
# Completed (w_t=20.00um, l_t=947.62um) [30389/30400]
# Completed (w_t=20.00um, l_t=952.38um) [30390/30400]
# Completed (w_t=20.00um, l_t=957.14um) [30391/30400]
# Completed (w_t=20.00um, l_t=961.90um) [30392/30400]
# Completed (w_t=20.00um, l_t=966.67um) [30393/30400]
# Completed (w_t=20.00um, l_t=971.43um) [30394/30400]
# Completed (w_t=20.00um, l_t=976.19um) [30395/30400]
# Completed (w_t=20.00um, l_t=980.95um) [30396/30400]
# Completed (w_t=20.00um, l_t=985.71um) [30397/30400]
# Completed (w_t=20.00um, l_t=990.48um) [30398/30400]
# Completed (w_t=20.00um, l_t=995.24um) [30399/30400]
# Completed (w_t=20.00um, l_t=1000.00um) [30400/30400]
# /var/folders/n7/v600f1k91rjfkqj_812w6ts40000gn/T/ipykernel_99561/1793193979.py:85: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['freq', 'm_c'], dtype='object')]
#
#   store['data'] = results_df
# 数据生成完成！所有 (w_t, l_t) 响应谱已写入 HDF5 文件。

# %% [markdown]
# ## 4. 数据可视化与有效性检测
#
# ### 检查数据集中 $(w_t, l_t)$ 组合的 NaN 分布与对称性
# 本部分代码用于统计每组 $(w_t, l_t)$ 下频率 (freq) 和电流 (m_c) 数据中 NaN 值的数量，并判断这些 NaN 是否在 $\phi$ 区间上关于中心对称（即 $i$ 是 NaN 则 $N-1-i$ 也为 NaN）。该分析有助于理解数值解失效的物理机制，并为后续数据清洗与建模提供依据。
# 所有结果将以表格形式展示，并写入原始数据的 .h5 文件，便于后续查阅与可视化。

# %%
import numpy as np
import pandas as pd
with pd.HDFStore('./data/wt_lt_big.h5', 'r') as store:
    results_df = store['data']
    # 如果你需要常数参数，可同时加载
    constants = store.get_storer('data').attrs.constants

N = len(constants['phi'])  # phi采样点数
mid = N // 2
nan_stats = []
for idx, row in results_df.iterrows():
    w_t = row['w_t']
    l_t = row['l_t']
    freq = np.array(row['freq'])
    m_c = np.array(row['m_c'])
    n_nan_freq = np.isnan(freq).sum()
    n_nan_mc = np.isnan(m_c).sum()
    nan_idx = np.where(np.isnan(freq))[0]
    # 检查是否两侧对称
    is_symmetric = all(((N-1-i) in nan_idx) for i in nan_idx)
    # 判断有效性
    valid = 1 if (n_nan_freq / len(freq) if len(freq) else 1) <= 0.2 else 0
    if n_nan_freq > 0 or n_nan_mc > 0:
        nan_stats.append({
            'w_t': w_t,
            'l_t': l_t,
            'n_nan_freq': n_nan_freq,
            'n_nan_mc': n_nan_mc,
            'freq_nan_ratio': n_nan_freq / len(freq) if len(freq) else np.nan,
            'mc_nan_ratio': n_nan_mc / len(m_c) if len(m_c) else np.nan,
            'n_nan': len(nan_idx),
            'is_symmetric': is_symmetric,
            'valid': valid,
            'nan_idx':nan_idx
        })
    

nan_df = pd.DataFrame(nan_stats)
display(nan_df)


# 保存 nan_symmetry_df（只保留关键字段）到原 .h5 文件
with pd.HDFStore('./data/wt_lt_big.h5', 'a') as store:
    store['nan'] = nan_df
print("nan对称性统计结果已写入wt_lt.h5文件，可随时通过['nan_symmetry']读取。")
# Out:
#            w_t       l_t  n_nan_freq  n_nan_mc  freq_nan_ratio  mc_nan_ratio  \
# 0     0.000007  0.000100           2         2        0.012422      0.012422
# 1     0.000007  0.000100           2         2        0.012422      0.012422
# 2     0.000007  0.000100           2         2        0.012422      0.012422
# 3     0.000007  0.000100           4         4        0.024845      0.024845
# 4     0.000007  0.000100           4         4        0.024845      0.024845
# ...        ...       ...         ...       ...             ...           ...
# 4810  0.000020  0.000186          10        10        0.062112      0.062112
# 4811  0.000020  0.000190           8         8        0.049689      0.049689
# 4812  0.000020  0.000195           6         6        0.037267      0.037267
# 4813  0.000020  0.000200           4         4        0.024845      0.024845
# 4814  0.000020  0.000205           2         2        0.012422      0.012422
#
#       n_nan  is_symmetric  valid                                   nan_idx
# 0         2          True      1                                  [0, 160]
# 1         2          True      1                                  [0, 160]
# 2         2          True      1                                  [0, 160]
# 3         4          True      1                          [0, 1, 159, 160]
# 4         4          True      1                          [0, 1, 159, 160]
# ...     ...           ...    ...                                       ...
# 4810     10          True      1  [0, 1, 2, 3, 4, 156, 157, 158, 159, 160]
# 4811      8          True      1          [0, 1, 2, 3, 157, 158, 159, 160]
# 4812      6          True      1                  [0, 1, 2, 158, 159, 160]
# 4813      4          True      1                          [0, 1, 159, 160]
# 4814      2          True      1                                  [0, 160]
#
# [4815 rows x 10 columns]
# nan对称性统计结果已写入wt_lt.h5文件，可随时通过['nan_symmetry']读取。
# /var/folders/n7/v600f1k91rjfkqj_812w6ts40000gn/T/ipykernel_99561/4051206659.py:44: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block3_values] [items->Index(['nan_idx'], dtype='object')]
#
#   store['nan'] = nan_df

# %% [markdown]
# ### 可视化 $(w_t, l_t)$ 参数空间中 freq 数据 NaN 的反色分布
# 本图采用反色色标（如magma_r），主参数区间显示为浅色，NaN数量多的区域显示为深色。这样可以让绝大多数无异常的$(w_t, l_t)$组合保持明亮，极少数数值失效的“危险区域”突出为黑色或深色，便于一眼锁定数值不稳定区间。

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. 构建 grid
w_t_vals = sorted(nan_df['w_t'].unique())
l_t_vals = sorted(nan_df['l_t'].unique())
grid = nan_df.pivot(index='l_t', columns='w_t', values='n_nan').values

# 2. 绘制 imshow，并用 extent 设置坐标范围
plt.figure(figsize=(8,6))
im = plt.imshow(
    grid,
    extent=[w_t_vals[0]*1e6, w_t_vals[-1]*1e6, l_t_vals[0]*1e6, l_t_vals[-1]*1e6],
    aspect='auto', origin='lower', cmap='magma_r'
)
plt.xlabel(r'Beam Width $w_t$ ($\mu$m)')
plt.ylabel(r'Beam Length $l_t$ ($\mu$m)')
plt.title('NaN count in freq per ($w_t$, $l_t$)')

# 设置每隔多少个 tick 显示一次（比如每隔 2 个）
w_step = 10
l_step = 10

plt.xticks(np.round(np.array(w_t_vals[::w_step]) * 1e6, 2))
plt.yticks(np.round(np.array(l_t_vals[::l_step]) * 1e6, 2))


# 4. 可选：更优美的colorbar
plt.colorbar(im, label='NaN count')

plt.tight_layout()
plt.savefig('./viz/wt_lt_nan_count_big.png', dpi=300)
plt.show()

# %% [markdown]
# ### 根据完整参数空间，自动生成每组 $(w_t, l_t)$ 下无 nan 的有效响应区间，并保存到 data_valid
# 本步骤遍历所有参数组合，对无 nan 样本直接全部保留，对有 nan 的样本则参考 nan_idx 剔除无效采样点，统一保存到 data_valid。这样所有可用参数样本均被整合，不会遗漏无缺失数据组。

# %%
import pandas as pd
import numpy as np

with pd.HDFStore('./data/wt_lt_big.h5', 'r') as store:
    results_df = store['data']
    constants = store.get_storer('data').attrs.constants
    nan_df = store['nan']

phi = np.array(constants['phi'])

# 构建 (w_t, l_t) -> nan信息的字典
nan_info_dict = {}
for _, row in nan_df.iterrows():
    key = (row['w_t'], row['l_t'])
    nan_info_dict[key] = {
        'valid': row['valid'],
        'nan_idx': np.array(row['nan_idx'], dtype=np.int_)
    }

data_valid = []
for idx, row in results_df.iterrows():
    w_t, l_t = row['w_t'], row['l_t']
    key = (w_t, l_t)
    freq = np.array(row['freq'])
    m_c = np.array(row['m_c'])
    # 如果有nan信息
    if key in nan_info_dict:
        nan_info = nan_info_dict[key]
        # valid==0直接跳过
        if nan_info['valid'] != 1:
            continue
        # 剔除nan点
        all_idx = np.arange(len(freq))
        valid_idx = np.setdiff1d(all_idx, nan_info['nan_idx'])
        freq = freq[valid_idx]
        m_c = m_c[valid_idx]
        phi_valid = phi[valid_idx]
    else:
        # 没有nan，全部保留
        phi_valid = phi
    # 计算统计量
    fmin, fmax = np.min(freq), np.max(freq)
    mmin, mmax = np.min(m_c), np.max(m_c)
    # center点（取phi=90度最近的点）
    phi_deg = phi_valid * 180 / np.pi
    idx_90 = np.argmin(np.abs(phi_deg - 90))
    freq_center = freq[idx_90]
    m_c_center = m_c[idx_90]

    entry = row.copy()
    entry['freq'] = freq
    entry['m_c'] = m_c
    entry['phi'] = phi_valid
    entry['freq_min'] = fmin
    entry['freq_max'] = fmax
    entry['freq_center'] = freq_center
    entry['m_c_min'] = mmin
    entry['m_c_max'] = mmax
    entry['m_c_center'] = m_c_center
    data_valid.append(entry)

results_valid_df = pd.DataFrame(data_valid)
print(f"有效参数组总数: {len(results_valid_df)}")

with pd.HDFStore('./data/wt_lt_big.h5', 'a') as store:
    store['data_valid'] = results_valid_df
print("已将所有有效响应数据（无nan）保存到 ['data_valid']，后续可直接调用。")
# Out:
# 有效参数组总数: 27480
# 已将所有有效响应数据（无nan）保存到 ['data_valid']，后续可直接调用。
# /var/folders/n7/v600f1k91rjfkqj_812w6ts40000gn/T/ipykernel_99561/3427106528.py:66: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['freq', 'm_c', 'phi'], dtype='object')]
#
#   store['data_valid'] = results_valid_df

# %% [markdown]
# ## 数据有效性与剔除NaN后的数据分布可视化
#
# 本部分用于对已剔除nan后的`data_valid`数据集进行多角度可视化和统计分析。
# 目的是**验证数据清洗效果、把握可用样本的分布特征，并为后续网络输入方案设计提供直观参考**。
#
# ### 1. 单样本完整响应曲线抽查
#
# 随机选取若干组样本，直接画出其\$\phi\$-freq和\$\phi\$-m\_c曲线，确认数据连续性与物理合理性。
#
# ### 2. 样本统计总览
#
# 包含参数分布的describe统计、样本起止点可视化等，辅助评估后续模型输入策略。
#
# ### 3. 样本有效区间的起止点分布
#
# 可视化所有样本剔除nan后有效$\phi$区间的位置，观察哪些\$\phi\$区间为主响应区，进一步优化采样或网络mask策略。
# ### 4.  $(w_t, l_t)$参数面有效长度分布
# 在参数面上直观展示每组参数下有效响应点的空间分布特征，发现“数据充足区”和“数据稀疏区”

# %%
import matplotlib.pyplot as plt

with pd.HDFStore('./data/wt_lt_big.h5', 'r') as store:
    results_df = store['data']
    constants = store.get_storer('data').attrs.constants
    results_valid_df = store['data_valid']

phi = np.array(constants['phi'])

phi_deg = lambda phi: np.array(phi) * 180 / np.pi

# 随机选择3个样本展示
samples = results_valid_df.sample(3, random_state=42)

for i, row in samples.iterrows():
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(phi_deg(row['phi']), row['freq'], 'b-')
    plt.xlabel(r'Phase $\phi$ (deg)')
    plt.ylabel('Frequency (Hz)')
    plt.title(f"$w_t$={row['w_t']*1e6:.1f}μm, $l_t$={row['l_t']*1e6:.1f}μm (freq)")

    plt.subplot(1,2,2)
    plt.plot(phi_deg(row['phi']), row['m_c'], 'r-')
    plt.xlabel(r'Phase $\phi$ (deg)')
    plt.ylabel('Motional Current (nA)')
    plt.title(f"$w_t$={row['w_t']*1e6:.1f}μm, $l_t$={row['l_t']*1e6:.1f}μm (m_c)")

    plt.tight_layout()
    plt.show()

# 简明统计
print(results_valid_df[['w_t', 'l_t']].describe())

# 头部、尾部
display(results_valid_df.head())
display(results_valid_df.tail())


for i, row in results_valid_df.iterrows():
    phi_vals = np.array(row['phi'])
    plt.plot([phi_vals[0]*180/np.pi, phi_vals[-1]*180/np.pi], [i, i], 'b-', alpha=0.3)

plt.xlabel(r'Phase $\phi$ (deg)')
plt.ylabel('Sample index')
plt.title('Valid $\phi$ intervals for all samples')
plt.show()


w_t_list = sorted(results_valid_df['w_t'].unique())
l_t_list = sorted(results_valid_df['l_t'].unique())
wtlt_grid = np.full((len(l_t_list), len(w_t_list)), np.nan)
for i, l_t in enumerate(l_t_list):
    for j, w_t in enumerate(w_t_list):
        subset = results_valid_df[(results_valid_df['w_t']==w_t) & (results_valid_df['l_t']==l_t)]
        if len(subset) > 0:
            wtlt_grid[i, j] = len(subset.iloc[0]['freq'])

plt.figure(figsize=(8,6))
plt.imshow(wtlt_grid, extent=[w_t_list[0]*1e6, w_t_list[-1]*1e6, l_t_list[0]*1e6, l_t_list[-1]*1e6],
           aspect='auto', origin='lower', cmap='magma')
plt.xlabel(r'Beam Width $w_t$ ($\mu$m)')
plt.ylabel(r'Beam Length $l_t$ ($\mu$m)')
plt.title('Number of Valid Points after NaN Removal in $(w_t, l_t)$')
plt.colorbar(label='Valid freq/m_c points')
plt.tight_layout()
plt.show()
# Out:
#                 w_t           l_t
# count  27480.000000  27480.000000
# mean       0.000012      0.000583
# std        0.000004      0.000248
# min        0.000005      0.000100
# 25%        0.000008      0.000376
# 50%        0.000012      0.000590
# 75%        0.000015      0.000795
# max        0.000020      0.001000
#         w_t       l_t  m_coef_b    k_coef_b  k_coef_b3         k_tt  \
# 0  0.000005  0.000100  0.396481  198.450892  12.564205  8733.906424
# 1  0.000005  0.000105  0.396481  198.450892  12.564205  7596.234728
# 2  0.000005  0.000110  0.396481  198.450892  12.564205  6647.876008
# 3  0.000005  0.000114  0.396481  198.450892  12.564205  5851.034967
# 4  0.000005  0.000119  0.396481  198.450892  12.564205  5176.621273
#
#            k_t3          Mass       omega_0         freq_0  ...          k_e3  \
# 0  2.654188e+14  8.503475e-10  3.204838e+06  510065.764142  ...  1.991705e+09
# 1  2.308456e+14  8.508974e-10  2.987862e+06  475533.066487  ...  1.991705e+09
# 2  2.020255e+14  8.514473e-10  2.794233e+06  444715.949112  ...  1.991705e+09
# 3  1.778099e+14  8.519972e-10  2.620579e+06  417078.116609  ...  1.991705e+09
# 4  1.573148e+14  8.525470e-10  2.464132e+06  392178.833972  ...  1.991705e+09
#
#                                                 freq  \
# 0  [509920.10146361956, 509933.53112284007, 50994...
# 1  [475397.1193583882, 475409.6397970529, 475420....
# 2  [444588.6623870562, 444600.3714336996, 444610....
# 3  [416958.58723446453, 416969.5685973574, 416978...
# 4  [392066.2838912764, 392076.60967446235, 392085...
#
#                                                  m_c  \
# 0  [0.001474128655685277, 0.0016198097303767487, ...
# 1  [0.0015801564696394052, 0.0017363157653629787,...
# 2  [0.0016885640665375012, 0.0018554367658435412,...
# 3  [0.0017992953548858033, 0.001977111097070995, ...
# 4  [0.0019122977183286215, 0.0021012809428672275,...
#
#                                                  phi       freq_min  \
# 0  [0.17453292519943295, 0.19198621771937624, 0.2...  509920.101464
# 1  [0.17453292519943295, 0.19198621771937624, 0.2...  475397.119358
# 2  [0.17453292519943295, 0.19198621771937624, 0.2...  444588.662387
# 3  [0.17453292519943295, 0.19198621771937624, 0.2...  416958.587234
# 4  [0.17453292519943295, 0.19198621771937624, 0.2...  392066.283891
#
#         freq_max    freq_center   m_c_min   m_c_max  m_c_center
# 0  510209.374133  510064.717377  0.001474  0.008489    0.008489
# 1  475666.807562  475531.944447  0.001580  0.009100    0.009100
# 2  444840.873335  444714.750110  0.001689  0.009724    0.009724
# 3  417195.123988  417076.838999  0.001799  0.010362    0.010362
# 4  392288.699560  392177.476146  0.001912  0.011012    0.011012
#
# [5 rows x 22 columns]
#            w_t       l_t  m_coef_b    k_coef_b  k_coef_b3        k_tt  \
# 30395  0.00002  0.000981  0.396481  198.450892  12.564205  592.167723
# 30396  0.00002  0.000986  0.396481  198.450892  12.564205  583.626975
# 30397  0.00002  0.000990  0.396481  198.450892  12.564205  575.249683
# 30398  0.00002  0.000995  0.396481  198.450892  12.564205  567.031955
# 30399  0.00002  0.001000  0.396481  198.450892  12.564205  558.970011
#
#                k_t3          Mass        omega_0         freq_0  ...  \
# 30395  1.124729e+12  1.291903e-09  677029.312007  107752.561624  ...
# 30396  1.108507e+12  1.294102e-09  671557.795545  106881.742733  ...
# 30397  1.092596e+12  1.296302e-09  666154.779866  106021.826080  ...
# 30398  1.076988e+12  1.298501e-09  660819.096390  105172.625680  ...
# 30399  1.061675e+12  1.300701e-09  655549.601816  104333.959571  ...
#
#                k_e3                                               freq  \
# 30395  1.991705e+09  [107718.74940904015, 107721.58645677107, 10772...
# 30396  1.991705e+09  [106848.15642887796, 106850.97054861739, 10685...
# 30397  1.991705e+09  [105988.46257182812, 105991.25405062451, 10599...
# 30398  1.991705e+09  [105139.48190528079, 105142.25102528585, 10514...
# 30399  1.991705e+09  [104301.03251908087, 104303.7795576553, 104306...
#
#                                                      m_c  \
# 30395  [0.00459304415544787, 0.005046952710912439, 0....
# 30396  [0.004622595782781223, 0.005079424784037412, 0...
# 30397  [0.004652181403036187, 0.00511193420944163, 0....
# 30398  [0.00468180079073397, 0.005144480739363315, 0....
# 30399  [0.004711453722520558, 0.00517706412837544, 0....
#
#                                                      phi       freq_min  \
# 30395  [0.17453292519943295, 0.19198621771937624, 0.2...  107718.749409
# 30396  [0.17453292519943295, 0.19198621771937624, 0.2...  106848.156429
# 30397  [0.17453292519943295, 0.19198621771937624, 0.2...  105988.462572
# 30398  [0.17453292519943295, 0.19198621771937624, 0.2...  105139.481905
# 30399  [0.17453292519943295, 0.19198621771937624, 0.2...  104301.032519
#
#             freq_max    freq_center   m_c_min   m_c_max  m_c_center
# 30395  107779.858923  107749.300079  0.004593  0.026450    0.026450
# 30396  106908.772077  106878.460206  0.004623  0.026620    0.026620
# 30397  106048.590537  106018.522547  0.004652  0.026791    0.026791
# 30398  105199.128265  105169.301118  0.004682  0.026961    0.026961
# 30399  104360.203248  104330.613955  0.004711  0.027132    0.027132
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact, fixed, Dropdown, Button, HBox, VBox, Output
import pandas as pd


with pd.HDFStore('./data/wt_lt_big.h5', 'r') as store:
    results_df = store['data']
    # 如果你需要常数参数，可同时加载
    constants = store.get_storer('data').attrs.constants
    results_valid_df = store['data_valid']

# 确保w_t_list, l_t_list为有序唯一数组
w_t_list = sorted(results_valid_df['w_t'].unique())
l_t_list = sorted(results_valid_df['l_t'].unique())
phi_deg = constants['phi'] * 180 / np.pi

# 生成可选项映射（μm显示更友好）
w_t_choices = {f'{w*1e6:.2f} μm': w for w in w_t_list}
l_t_choices = {f'{l*1e6:.2f} μm': l for l in l_t_list}

# 下拉框
w_t_dropdown = Dropdown(
    options=w_t_choices,
    value=w_t_list[0],
    description='w_t:',
    style={'description_width': 'initial'},
    layout={'width': '200px'}
)
l_t_dropdown = Dropdown(
    options=l_t_choices,
    value=l_t_list[0],
    description=r'l_t:',
    style={'description_width': 'initial'},
    layout={'width': '200px'}
)

btn = Button(description="显示", button_style='success')
out = Output()

def plot_selected(w_t, l_t):
    with out:
        out.clear_output()
        row = results_df[(results_df['w_t']==w_t) & (results_df['l_t']==l_t)].iloc[0]
        freq = np.array(row['freq'])
        m_c = np.array(row['m_c'])
        fig, axs = plt.subplots(1, 2, figsize=(12,5))
        axs[0].plot(phi_deg, freq, 'b-', lw=2)
        axs[0].set_xlabel(r'Phase $\phi$ (deg)')
        axs[0].set_ylabel('Frequency (Hz)')
        axs[0].set_title(rf'Frequency ($w_t$={w_t*1e6:.2f}$\mu$m, $l_t$={l_t*1e6:.2f}$\mu$m)')
        axs[0].grid(True)
        axs[1].plot(phi_deg, m_c, 'r-', lw=2)
        axs[1].set_xlabel(r'Phase $\phi$ (deg)')
        axs[1].set_ylabel('Motional Current (nA)')
        axs[1].set_title(rf'Motional Current ($w_t$={w_t*1e6:.2f}$\mu$m, $l_t$={l_t*1e6:.2f}$\mu$m)')
        axs[1].grid(True)
        plt.tight_layout()
        plt.show()

def on_click(btn):
    plot_selected(w_t_dropdown.value, l_t_dropdown.value)

btn.on_click(on_click)

ui = HBox([w_t_dropdown, l_t_dropdown, btn])
display(VBox([ui, out]))

# 初始化一次
plot_selected(w_t_dropdown.value, l_t_dropdown.value)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='w_t:', layout=Layout(width='200px'), options={'5.00 μm': n…
